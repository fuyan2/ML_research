# %% [markdown]
# <a href="https://colab.research.google.com/github/fuyan2/ML_research/blob/master/simple_gan_max_loss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import division, print_function, absolute_import

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random

tf.reset_default_graph()
tf.set_random_seed(1)

# Training Params
num_steps = 100000
learning_rate = 0.00002
x_dim = 2
noise_dim = 20
NUM_LABEL = 1
GAN_CLASS_COE = 500
gan_batch_size = 1000

# A custom initialization (see Xavier Glorot init)
def glorot_init(shape):
    return tf.random_normal(shape=shape, stddev=1. / tf.sqrt(shape[0] / 2.), dtype=tf.float32)
 
# Linear Regression 
class Generator(object):
  # G Parameters
  def __init__(self, noise_dim, NUM_LABEL, batch_size):
    self.batch_size = batch_size
    self.linear_w1 = tf.Variable(glorot_init([noise_dim+NUM_LABEL, 100]),name='glw1')
    self.linear_b1 = tf.Variable(glorot_init([100]),name='glb1')
    self.linear_w2 = tf.Variable(glorot_init([100, 50]),name='glw2')
    self.linear_b2 = tf.Variable(glorot_init([50]),name='glb2')
    self.linear_w3 = tf.Variable(glorot_init([50, x_dim]),name='glw3')
    self.linear_b3 = tf.Variable(glorot_init([x_dim]),name='glb3')
    
    self.training = True

 # Build G Graph
  def __call__(self, z,y):
    z_y = tf.concat((z,y),1)
    linear_z1 = tf.nn.leaky_relu(tf.matmul(z_y,self.linear_w1) + self.linear_b1)
    linear_z2 = tf.nn.leaky_relu(tf.matmul(linear_z1,self.linear_w2) + self.linear_b2)
    out_layer = tf.matmul(linear_z2,self.linear_w3)+self.linear_b3
    return out_layer

# Logistic Regression
class Disciminator(object):
  # D Parameters
  def __init__(self):
    self.linear_w1 = tf.Variable(glorot_init([x_dim, 100]))
    self.linear_b1 = tf.Variable(glorot_init([100]))
    self.linear_w2 = tf.Variable(glorot_init([100, 1]))
    self.linear_b2 = tf.Variable(glorot_init([1]))

    self.training = True

  # Build D Graph
  def __call__(self, x):
    linear1 = tf.nn.leaky_relu(tf.matmul(x, self.linear_w1) + self.linear_b1)
    out = tf.matmul(linear1, self.linear_w2) + self.linear_b2
    out = tf.sigmoid(out)
    return out

class Classifier(object):
  def __init__(self):
    self.linear_w1 = tf.Variable(glorot_init([x_dim, 100]))
    self.linear_b1 = tf.Variable(glorot_init([100]))
    self.linear_w2 = tf.Variable(glorot_init([100, NUM_LABEL]))
    self.linear_b2 = tf.Variable(glorot_init([NUM_LABEL]))

    self.training = True

  # Build D Graph
  def __call__(self, x):
    linear1 = tf.nn.leaky_relu(tf.matmul(x, self.linear_w1) + self.linear_b1)
    out = tf.matmul(linear1, self.linear_w2) + self.linear_b2
    out = tf.sigmoid(out)
    return out
  
  
def plot_gan_image(name, epoch, sess):
  # Generate images from noise, using the generator network.
  fig, ax = plt.subplots()
  for i in range(2):
#   i = 0    
    # Desired label
    d_label = np.zeros([gan_batch_size, NUM_LABEL])
    d_label[:] = i
    # Noise input.
    z = np.random.uniform(-1., 1., size=[gan_batch_size, noise_dim])
    g = sess.run([gen_sample], feed_dict={gen_input: z, desired_label: d_label})
    g = np.reshape(g, [gan_batch_size,2])
    if i == 0:
      ax.scatter(g[:,0], g[:,1], c='r')
    if i == 1:
      ax.scatter(g[:,0], g[:,1], c='b')
     
  # f.show()
  plt.savefig(name+epoch)

# Build Dataset
features = tf.placeholder(tf.float32, shape=[None, x_dim])
labels = tf.placeholder(tf.float32, shape=[None, NUM_LABEL])
batch_size = tf.placeholder(tf.int64)
sample_size = tf.placeholder(tf.int64)
dataset = tf.data.Dataset.from_tensor_slices((features, labels))
dataset = dataset.shuffle(sample_size, reshuffle_each_iteration=True)
dataset = dataset.batch(batch_size, drop_remainder=True).repeat()
iter = dataset.make_initializable_iterator()
next_batch = iter.get_next()

mu1 = [0., 0.]
sigma1 = [[1., 0.], [0., 1.]]
mu2 = [50., 0.]
sigma2 = [[1., 0.], [0., 1.]]
x_1 = np.random.multivariate_normal(mu1, sigma1, 10000)
x_2 = np.random.multivariate_normal(mu2, sigma2, 10000)
plt.scatter(x_1[:,0], x_1[:,1], c='r')
plt.scatter(x_2[:,0], x_2[:,1], c='b')
y_1 = np.zeros(10000)
y_2 = np.ones(10000)
x_train = np.concatenate((x_1, x_2), axis=0)
y_train = np.concatenate((y_1, y_2), axis=0)
y_train= y_train.reshape([20000, 1])
# train_data = np.concatenate((x_train, y_train), axis=1)
# print(train_data.shape, train_data)
# train_data = tf.random.shuffle(train_data)
# print(train_data.shape, train_data)
# x_train = train_data[:,0:1]
# y_train = train_data[:, 2]

#aux_data is same as data1
mu3 = [1., 1.]
mu4 = [6., 6.]

aux_data1 = np.random.multivariate_normal(mu2, sigma1, 500)
aux_data2 = np.random.multivariate_normal(mu2, sigma1, 500)
aux_data = np.concatenate((aux_data1, aux_data2), axis=0)
plt.scatter(aux_data[:,0], aux_data[:,1], c='y')

# plt.close()

# Build The Classifier
x = tf.placeholder(tf.float32, shape=[None, x_dim])
y = tf.placeholder(tf.float32, shape=[None, NUM_LABEL])
model = Classifier()
y_ml = model(x)
model_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(labels=y, logits=y_ml))

y_pred = tf.math.greater(y_ml, 0.5)
correct = tf.equal(tf.math.greater(y_ml, 0.5), tf.math.greater(y, 0.5))
accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

model_optimizer = tf.train.AdamOptimizer(0.001).minimize(model_loss, var_list=[model.linear_w1, model.linear_b1, model.linear_w2, model.linear_b2])

# Build Networks
# Network Inputs
gen_input = tf.placeholder(tf.float32, shape=[None, noise_dim], name='input_noise')
aux_x = tf.placeholder(tf.float32, shape=[None, x_dim])
desired_label = tf.placeholder(tf.float32, shape=[None, NUM_LABEL], name='desired_label')
# Build G Network
G = Generator(noise_dim, NUM_LABEL, gan_batch_size)
gen_sample = G(gen_input,desired_label)

# Build 2 D Networks (one from noise input, one from generated samples)
D = Disciminator()
disc_real = D(aux_x)
disc_fake = D(gen_sample)

# Build Loss
#   y_ml = model(gen_sample)
gan_class_loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=desired_label, logits=y_ml))
gen_loss = -tf.reduce_mean(tf.log(tf.minimum(0.01, disc_fake))) + GAN_CLASS_COE*gan_class_loss
disc_loss = -tf.reduce_mean(tf.log(disc_real) + tf.log(1. - disc_fake))

# gen_loss = -tf.reduce_mean(disc_fake) + GAN_CLASS_COE*gan_class_loss
# disc_loss = -tf.reduce_mean(disc_real) + tf.reduce_mean(disc_fake) 

# Build Optimizers
optimizer_gen = tf.train.AdamOptimizer(learning_rate=learning_rate)
optimizer_disc = tf.train.AdamOptimizer(learning_rate=learning_rate)

# Training Variables for each optimizer
# By default in TensorFlow, all variables are updated by each optimizer, so we
# need to precise for each one of them the specific variables to update.
# G Network Variables
gen_vars = [G.linear_w1, G.linear_b1, G.linear_w2, G.linear_b2]
# D Network Variables
disc_vars = [D.linear_w1, D.linear_b1, D.linear_w2, D.linear_b2]

# Create training operations
train_gen = optimizer_gen.minimize(gen_loss, var_list=gen_vars)
train_disc = optimizer_disc.minimize(disc_loss, var_list=disc_vars)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/dataset_ops.py:1419: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
def train_gan():
  # mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)
  # Train Classifier
  
  # Initialize the variables (i.e. assign their default value)
  init = tf.global_variables_initializer()

  # Start training
  with tf.Session() as sess:

      # Run the initializer
      sess.run(init)

      sess.run(iter.initializer, feed_dict = {features: x_train, labels: y_train, batch_size: gan_batch_size, sample_size: 25000})

      # Train the Classifier First
      for i in range(2000):
        batch = sess.run(next_batch)
        model_optimizer.run(feed_dict={ x: batch[0], y: batch[1]})
        if i % 1000 == 0:
          train_accuracy = accuracy.eval(feed_dict={x: batch[0], y: batch[1] })
          print('Epoch %d, training accuracy %g' % (i, train_accuracy))    

      test_acc = accuracy.eval(feed_dict={x: x_train, y: y_train})
      print("test acc:", test_acc)
      y_prediction = y_pred.eval(feed_dict={x: x_train, y: y_train})

      cluster1 = []
      cluster2 = []
      for i in range(0, 20000):
        if y_prediction[i]:
          cluster2.append(x_train[i])
        else:
          cluster1.append(x_train[i])

      cluster1 = np.array(cluster1)
      cluster2 = np.array(cluster2)
      print('cluster1: ', cluster1.shape, 'cluster2: ', cluster2.shape)
      plt.scatter(cluster1[:,0], cluster1[:,1],c='r')
      plt.scatter(cluster2[:,0], cluster2[:,1],c='b')
      plt.savefig('Classifier_plot')
      
      #Train GAN
      for i in range(200000):
        batch_x = aux_data
        # Use one hot aux_label instead of distribution
        aux_label = sess.run(y_ml, feed_dict={x: batch_x})
        #Use one hot label
        aux_label = np.select([aux_label > 0.5, aux_label <= 0.5], [np.ones([gan_batch_size, 1]), np.zeros([gan_batch_size, 1])])
#         aux_label = np.zeros([gan_batch_size,1])
        # Sample random noise 
        z = np.random.uniform(-1., 1., size=[gan_batch_size, noise_dim])
        # Pass random noise into the generator and get generated image
        gen_mi = sess.run(gen_sample, feed_dict={gen_input:z, desired_label: aux_label}) 
       
        #! Train Discriminator
        train_disc.run(feed_dict={aux_x: batch_x,  gen_input: z, x: gen_mi, desired_label: aux_label})
        if i % 5 == 0:
          train_gen.run(feed_dict={aux_x: batch_x,  gen_input: z, x: gen_mi, desired_label: aux_label})
       
        if i % 2000 == 0:
          gl,dl = sess.run([gen_loss, disc_loss], feed_dict={aux_x: batch_x,  gen_input: z, x: gen_mi, desired_label: aux_label})
          print('Epoch %i: Generator Loss: %f, Discriminator Loss: %f' % (i, gl, dl))
          plot_gan_image('gan_out',str(i), sess)
      
      
if __name__ == '__main__':
  train_gan()
# Out:
# Epoch 0, training accuracy 0.612
# Epoch 1000, training accuracy 1
# test acc: 1.0
# cluster1:  (10000, 2) cluster2:  (10000, 2)
# Epoch 0: Generator Loss: 4.605165, Discriminator Loss: 1.870626
# Epoch 2000: Generator Loss: 4.605293, Discriminator Loss: 0.175217
# Epoch 4000: Generator Loss: 4.605165, Discriminator Loss: 0.135829
# Epoch 6000: Generator Loss: 4.605165, Discriminator Loss: 0.192059
# Epoch 8000: Generator Loss: 4.605165, Discriminator Loss: 0.257034
# Epoch 10000: Generator Loss: 4.605165, Discriminator Loss: 0.171561
# Epoch 12000: Generator Loss: 4.605165, Discriminator Loss: 0.089613
# Epoch 14000: Generator Loss: 4.606071, Discriminator Loss: 0.042135
# Epoch 16000: Generator Loss: 4.605229, Discriminator Loss: 0.019218
# Epoch 18000: Generator Loss: 4.611123, Discriminator Loss: 0.012737
# Epoch 20000: Generator Loss: 4.649779, Discriminator Loss: 0.012023
# Epoch 22000: Generator Loss: 4.763768, Discriminator Loss: 0.011371
# Epoch 24000: Generator Loss: 4.872902, Discriminator Loss: 0.010925
# Epoch 26000: Generator Loss: 4.938855, Discriminator Loss: 0.011344
# Epoch 28000: Generator Loss: 4.953787, Discriminator Loss: 0.012969
# Epoch 30000: Generator Loss: 4.922514, Discriminator Loss: 0.015278
# Epoch 32000: Generator Loss: 4.869487, Discriminator Loss: 0.020607
# Epoch 34000: Generator Loss: 4.790799, Discriminator Loss: 0.028479
# Epoch 36000: Generator Loss: 4.750199, Discriminator Loss: 0.041887
# Epoch 38000: Generator Loss: 4.724298, Discriminator Loss: 0.058787
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Epoch 40000: Generator Loss: 4.688300, Discriminator Loss: 0.090250
# Epoch 42000: Generator Loss: 4.664967, Discriminator Loss: 0.129852
# Epoch 44000: Generator Loss: 4.646878, Discriminator Loss: 0.188863
# Epoch 46000: Generator Loss: 4.646392, Discriminator Loss: 0.278334
# Epoch 48000: Generator Loss: 4.625962, Discriminator Loss: 0.369123
# Epoch 50000: Generator Loss: 4.618742, Discriminator Loss: 0.503492
# Epoch 52000: Generator Loss: 4.615354, Discriminator Loss: 0.652352
# Epoch 54000: Generator Loss: 4.608361, Discriminator Loss: 0.834493
# Epoch 56000: Generator Loss: 4.608878, Discriminator Loss: 0.984456
# Epoch 58000: Generator Loss: 4.607183, Discriminator Loss: 1.185498
# Epoch 60000: Generator Loss: 4.605830, Discriminator Loss: 1.255397
# Epoch 62000: Generator Loss: 4.606293, Discriminator Loss: 1.373328
# Epoch 64000: Generator Loss: 4.605165, Discriminator Loss: 1.453244
# Epoch 66000: Generator Loss: 4.605165, Discriminator Loss: 1.420228
# Epoch 68000: Generator Loss: 4.605165, Discriminator Loss: 1.473280
# Epoch 70000: Generator Loss: 4.605237, Discriminator Loss: 1.500592
# Epoch 72000: Generator Loss: 4.605165, Discriminator Loss: 1.484902
# Epoch 74000: Generator Loss: 4.605165, Discriminator Loss: 1.482269
# Epoch 76000: Generator Loss: 4.605165, Discriminator Loss: 1.493879
# Epoch 78000: Generator Loss: 4.605165, Discriminator Loss: 1.485694
# Epoch 80000: Generator Loss: 4.605165, Discriminator Loss: 1.466242
# Epoch 82000: Generator Loss: 4.605165, Discriminator Loss: 1.489988
# Epoch 84000: Generator Loss: 4.605165, Discriminator Loss: 1.461599
# Epoch 86000: Generator Loss: 4.605165, Discriminator Loss: 1.473937
# Epoch 88000: Generator Loss: 4.605165, Discriminator Loss: 1.478258
# Epoch 90000: Generator Loss: 4.605165, Discriminator Loss: 1.424475
# Epoch 92000: Generator Loss: 4.605165, Discriminator Loss: 1.457538
# Epoch 94000: Generator Loss: 4.605165, Discriminator Loss: 1.395376
# Epoch 96000: Generator Loss: 4.605165, Discriminator Loss: 1.456655
# Epoch 98000: Generator Loss: 4.605165, Discriminator Loss: 1.416660
# Epoch 100000: Generator Loss: 4.605165, Discriminator Loss: 1.426367
# Epoch 102000: Generator Loss: 4.605165, Discriminator Loss: 1.412298
# Epoch 104000: Generator Loss: 4.605165, Discriminator Loss: 1.403586
# Epoch 106000: Generator Loss: 4.605165, Discriminator Loss: 1.403264
# Epoch 108000: Generator Loss: 4.605165, Discriminator Loss: 1.375756
# Epoch 110000: Generator Loss: 4.605165, Discriminator Loss: 1.407629
# Epoch 112000: Generator Loss: 4.605165, Discriminator Loss: 1.403516
# Epoch 114000: Generator Loss: 4.605165, Discriminator Loss: 1.396819
# Epoch 116000: Generator Loss: 4.605165, Discriminator Loss: 1.369756
# Epoch 118000: Generator Loss: 4.605165, Discriminator Loss: 1.371040
# Epoch 120000: Generator Loss: 4.605165, Discriminator Loss: 1.377107
# Epoch 122000: Generator Loss: 4.605165, Discriminator Loss: 1.369056
# Epoch 124000: Generator Loss: 4.605165, Discriminator Loss: 1.376009
# Epoch 126000: Generator Loss: 4.605165, Discriminator Loss: 1.371233
# Epoch 128000: Generator Loss: 4.605165, Discriminator Loss: 1.386551
# Epoch 130000: Generator Loss: 4.605165, Discriminator Loss: 1.367356
# Epoch 132000: Generator Loss: 4.605165, Discriminator Loss: 1.369376
# Epoch 134000: Generator Loss: 4.605165, Discriminator Loss: 1.377085
# Epoch 136000: Generator Loss: 4.605165, Discriminator Loss: 1.386860
# Epoch 138000: Generator Loss: 4.605165, Discriminator Loss: 1.387067
# Epoch 140000: Generator Loss: 4.605165, Discriminator Loss: 1.372122
# Epoch 142000: Generator Loss: 4.605165, Discriminator Loss: 1.378805
# Epoch 144000: Generator Loss: 4.605165, Discriminator Loss: 1.375079
# Epoch 146000: Generator Loss: 4.605165, Discriminator Loss: 1.365658
# Epoch 148000: Generator Loss: 4.605165, Discriminator Loss: 1.367190
# Epoch 150000: Generator Loss: 4.605165, Discriminator Loss: 1.377961
# Epoch 152000: Generator Loss: 4.605165, Discriminator Loss: 1.380736
# Epoch 154000: Generator Loss: 4.605165, Discriminator Loss: 1.373407
# Epoch 156000: Generator Loss: 4.605165, Discriminator Loss: 1.378579
# Epoch 158000: Generator Loss: 4.605165, Discriminator Loss: 1.372711
# Epoch 160000: Generator Loss: 4.605165, Discriminator Loss: 1.376794
# Epoch 162000: Generator Loss: 4.605165, Discriminator Loss: 1.371029
# Epoch 164000: Generator Loss: 4.605165, Discriminator Loss: 1.372453
# Epoch 166000: Generator Loss: 4.605165, Discriminator Loss: 1.368208
# Epoch 168000: Generator Loss: 4.605165, Discriminator Loss: 1.365474
# Epoch 170000: Generator Loss: 4.605165, Discriminator Loss: 1.376517
# Epoch 172000: Generator Loss: 4.605165, Discriminator Loss: 1.374362
# Epoch 174000: Generator Loss: 4.605165, Discriminator Loss: 1.373227
# Epoch 176000: Generator Loss: 4.605165, Discriminator Loss: 1.363470
# Epoch 178000: Generator Loss: 4.605165, Discriminator Loss: 1.378205
# Epoch 180000: Generator Loss: 4.605165, Discriminator Loss: 1.378312
# Epoch 182000: Generator Loss: 4.605165, Discriminator Loss: 1.383552
# Epoch 184000: Generator Loss: 4.605165, Discriminator Loss: 1.377244
# Epoch 186000: Generator Loss: 4.605165, Discriminator Loss: 1.375736
# Epoch 188000: Generator Loss: 4.605165, Discriminator Loss: 1.371006
# Epoch 190000: Generator Loss: 4.605165, Discriminator Loss: 1.376587
# Epoch 192000: Generator Loss: 4.605165, Discriminator Loss: 1.371121
# Epoch 194000: Generator Loss: 4.605165, Discriminator Loss: 1.372264
# Epoch 196000: Generator Loss: 4.605165, Discriminator Loss: 1.373548
# Epoch 198000: Generator Loss: 4.605165, Discriminator Loss: 1.375049
