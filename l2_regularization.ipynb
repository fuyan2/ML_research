# %% [markdown]
# <a href="https://colab.research.google.com/github/fuyan2/ML_research/blob/master/l2_regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random
import math

inf = math.inf

tf.reset_default_graph()
tf.set_random_seed(1)

# Training Params
num_steps = 100000
learning_rate = 0.00002
x_dim = 2
noise_dim = 20
NUM_LABEL = 3
GAN_CLASS_COE = 10
gan_batch_size = 100*NUM_LABEL
num_data = 10000
INV_HIDDEN = 100
beta = 0 #1
lemda = 0.1
l2_coe = 0.05

#Fredrickson Params
ALPHA = 50000
BETA = 5
GAMMA = 1
LAMBDA = 0.06

# A custom initialization (see Xavier Glorot init)
def glorot_init(shape):
    return tf.random_normal(shape=shape, stddev=1. / tf.sqrt(shape[0] / 2.), dtype=tf.float32)

# Linear Regression 
class NN_attacker(object):
  def __init__(self, NUM_LABEL):
    self.linear_w1 = tf.Variable(glorot_init([NUM_LABEL, 10]),name='glw1')
    self.linear_b1 = tf.Variable(tf.zeros([10]),name='glb1')
    self.linear_w2 = tf.Variable(glorot_init([10, 5]),name='glw2')
    self.linear_b2 = tf.Variable(tf.zeros([5]),name='glb2')
    self.linear_w3 = tf.Variable(glorot_init([5, x_dim]),name='glw3')
    self.linear_b3 = tf.Variable(tf.zeros([x_dim]),name='glb3')

  def __call__(self, y):
    linear_z1 = tf.nn.leaky_relu(tf.matmul(y,self.linear_w1) + self.linear_b1)
    linear_z2 = tf.nn.leaky_relu(tf.matmul(linear_z1,self.linear_w2) + self.linear_b2)
    out_layer = tf.matmul(linear_z2,self.linear_w3)+self.linear_b3
    return out_layer
  
# Linear Regression 
class Generator(object):
  # G Parameters
  def __init__(self, noise_dim, NUM_LABEL, batch_size):
    self.batch_size = batch_size
    self.linear_w1 = tf.Variable(glorot_init([noise_dim+NUM_LABEL, 100]),name='glw1')
    self.linear_b1 = tf.Variable(tf.zeros([100]),name='glb1')
    self.linear_w2 = tf.Variable(glorot_init([100, 50]),name='glw2')
    self.linear_b2 = tf.Variable(tf.zeros([50]),name='glb2')
    self.linear_w3 = tf.Variable(glorot_init([50, x_dim]),name='glw3')
    self.linear_b3 = tf.Variable(tf.zeros([x_dim]),name='glb3')
    
    self.training = True

 # Build G Graph
  def __call__(self, z,y):
    z_y = tf.concat((z,y),1)
    linear_z1 = tf.nn.leaky_relu(tf.matmul(z_y,self.linear_w1) + self.linear_b1)
    linear_z2 = tf.nn.leaky_relu(tf.matmul(linear_z1,self.linear_w2) + self.linear_b2)
    out_layer = tf.matmul(linear_z2,self.linear_w3)+self.linear_b3
    return out_layer

# Logistic Regression
class Disciminator(object):
  # D Parameters
  def __init__(self):
    self.linear_w1 = tf.Variable(glorot_init([x_dim + NUM_LABEL, 100]))
    self.linear_b1 = tf.Variable(tf.zeros([100]))
    self.linear_w2 = tf.Variable(glorot_init([100, 1]))
    self.linear_b2 = tf.Variable(tf.zeros([1]))

    self.training = True

  # Build D Graph
  def __call__(self, x, y):
    x_y = tf.concat((x,y),1)
    linear1 = tf.nn.relu(tf.matmul(x_y, self.linear_w1) + self.linear_b1)
    out = tf.matmul(linear1, self.linear_w2) + self.linear_b2
    out = tf.sigmoid(out)
    return out

class Classifier(object):
  def __init__(self):
    self.linear_w1 = tf.Variable(glorot_init([x_dim, NUM_LABEL]))
    self.linear_b1 = tf.Variable(tf.zeros([NUM_LABEL]))
#     self.linear_w2 = tf.Variable(glorot_init([1, NUM_LABEL]))
#     self.linear_b2 = tf.Variable(tf.zeros([NUM_LABEL]))

    self.training = True

  # Build D Graph
  def __call__(self, x):
#     linear1 = tf.nn.relu(tf.matmul(x, self.linear_w1) + self.linear_b1)
#     out = tf.nn.softmax(tf.matmul(linear1, self.linear_w2) + self.linear_b2)
    out = tf.nn.softmax(tf.matmul(x, self.linear_w1) + self.linear_b1)
    return out
  
def lrelu(x, alpha):
  return tf.nn.relu(x) - alpha * tf.nn.relu(-x)

class Inverter_Regularizer(object):
  def __init__(self, weight_shape):
    self.w_model =  tf.Variable(glorot_init([weight_shape, INV_HIDDEN]))
    self.w_label = tf.Variable(glorot_init([NUM_LABEL, INV_HIDDEN]))
    self.w_out = tf.Variable(glorot_init([INV_HIDDEN, x_dim]))
    self.b_in = tf.Variable(tf.zeros([INV_HIDDEN]))
    self.b_out = tf.Variable(tf.zeros([x_dim]))
    
  def __call__(self, y, model_weights):
    # Input Layer
    ww = tf.matmul(model_weights, self.w_model)
    wy = tf.matmul(y, self.w_label)
    wt = tf.add(wy, ww)
    hidden_layer =  tf.add(wt, self.b_in)
    rect = lrelu(hidden_layer, 0.3)
    # Output Layer
    out_layer = tf.add(tf.matmul(rect, self.w_out), self.b_out)
    rect = lrelu(out_layer, 0.3)
    return rect
  
def plot_gan_image(name, epoch, sess):
  # Generate images from noise, using the generator network.
  fig, ax = plt.subplots()
  for i in range(NUM_LABEL):   
    # Desired label
    d_label = np.zeros([gan_batch_size, NUM_LABEL])
    d_label[:, i] = 1
    # Noise input.
    z = np.random.uniform(-1., 1., size=[gan_batch_size, noise_dim])
    g = sess.run([gen_sample], feed_dict={gen_input: z, desired_label: d_label})
    g = np.reshape(g, [gan_batch_size,2])
    if i == 0:
      ax.scatter(g[:,0], g[:,1], c='r')
    elif i == 1:
      ax.scatter(g[:,0], g[:,1], c='b')
    elif i == 2:
      ax.scatter(g[:,0], g[:,1], c='g')
      
  plt.savefig(name+epoch)

def plot_nn_image(name, epoch, sess):
  # Generate images from noise, using the generator network.
  inverted_x = np.zeros((NUM_LABEL, x_dim))
  for i in range(NUM_LABEL):   
    # Desired label
    d_label = np.zeros([1, NUM_LABEL])
    d_label[:, i] = 1
    # Noise input.
    g = sess.run([nn_x], feed_dict={target_y:d_label})
    inverted_x[i] = np.reshape(g,[x_dim])
      
  plt.scatter(inverted_x[:,0], inverted_x[:,1], marker='^', c='b')
  plt.savefig(name+epoch)
#   plt.close()
  
###################### Build Dataset #############################
features = tf.placeholder(tf.float32, shape=[None, x_dim])
labels = tf.placeholder(tf.float32, shape=[None, NUM_LABEL])
batch_size = tf.placeholder(tf.int64)
sample_size = tf.placeholder(tf.int64)
dataset = tf.data.Dataset.from_tensor_slices((features, labels))
dataset = dataset.shuffle(sample_size, reshuffle_each_iteration=True)
dataset = dataset.batch(batch_size, drop_remainder=True).repeat()
iterator = dataset.make_initializable_iterator()
next_batch = iterator.get_next()

mu1 = [0., 0.]
sigma1 = [[1., 0.], [0., 1.]]
mu2 = [10., 0.]
sigma2 = [1., 0.5]
mu3 = [5., 10.]
x_1 = np.random.multivariate_normal(mu1, sigma1, num_data)
x_2 = np.random.multivariate_normal(mu2, sigma1, num_data)
x_3 = np.random.multivariate_normal(mu3, sigma1, num_data)

# x_1 = np.random.laplace(mu1,sigma2, [num_data, 2])
# x_2 = np.random.laplace(mu2,sigma2, [num_data, 2])
# x_3 = np.random.laplace(mu3,sigma2, [num_data, 2])

plt.scatter(x_1[:,0], x_1[:,1], c='r')
plt.scatter(x_2[:,0], x_2[:,1], c='b')
plt.scatter(x_3[:,0], x_3[:,1], c='g')

# !label=3
x_train = np.concatenate((x_1, x_2, x_3), axis=0)
y_train = np.zeros([num_data*NUM_LABEL, NUM_LABEL])
for i in range(NUM_LABEL):
  y_train[i*num_data:(i+1)*num_data, i] = 1.
  
#aux_data is same as data1
aux_mu1 = [0., 0.]
aux_mu2 = [10., 0.]
aux_mu3 = [5., 10.]

aux_data1 = np.random.multivariate_normal(aux_mu1, sigma1, 1000)
aux_data2 = np.random.multivariate_normal(aux_mu2, sigma1, 1000)
aux_data3 = np.random.multivariate_normal(aux_mu3, sigma1, 1000)

# aux_data1 = np.random.laplace(aux_mu1, sigma2, [1000,2])
# aux_data2 = np.random.laplace(aux_mu2, sigma2, [1000,2])
# aux_data3 = np.random.laplace(aux_mu3, sigma2, [1000,2])

aux_data = np.concatenate((aux_data1, aux_data2, aux_data3), axis=0)
# random.shuffle(aux_data)
plt.scatter(aux_data[:,0], aux_data[:,1], c='y')


################### Build The Classifier ####################
x = tf.placeholder(tf.float32, shape=[None, x_dim])
y = tf.placeholder(tf.float32, shape=[None, NUM_LABEL])
model = Classifier()
y_ml = model(x)
# Build Inverter Regularizer
model_weights = tf.concat([tf.reshape(model.linear_w1,[1, -1]),tf.reshape(model.linear_b1,[1, -1])] ,1) #, tf.reshape(model.linear_w2,[1, -1]), tf.reshape(model.linear_b2,[1, -1])], 1)
weight_shape = int(model_weights.shape[1])
inverter = Inverter_Regularizer(weight_shape)
inv_x = inverter(y, model_weights)

#################### Build GAN Networks ############################
# Network Inputs
gen_input = tf.placeholder(tf.float32, shape=[None, noise_dim], name='input_noise')
aux_x = tf.placeholder(tf.float32, shape=[None, x_dim])
aux_label = model(aux_x)
desired_label = tf.one_hot(tf.argmax(aux_label, 1), NUM_LABEL) 

# Build G Network
G = Generator(noise_dim, NUM_LABEL, gan_batch_size)
gen_sample = G(gen_input,desired_label)
gen_label =  model(gen_sample)

# Build 2 D Networks (one from noise input, one from generated samples)
D = Disciminator()
disc_real = D(aux_x, desired_label)
disc_fake = D(gen_sample, desired_label)

# Build Loss
gen_weights = tf.concat([tf.reshape(G.linear_w1,[1, -1]),tf.reshape(G.linear_b1,[1, -1]), tf.reshape(G.linear_w2,[1, -1]), tf.reshape(G.linear_b2,[1, -1]), tf.reshape(G.linear_w3,[1, -1]), tf.reshape(G.linear_b3,[1, -1])], 1)
gan_class_loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=desired_label, logits=gen_label)) + 0.001 * tf.nn.l2_loss(gen_weights)
gen_loss = -tf.reduce_mean(tf.log(tf.maximum(0.00001, disc_fake))) + GAN_CLASS_COE*gan_class_loss
disc_loss = -tf.reduce_mean(tf.log(tf.maximum(0.0000001, disc_real)) + tf.log(tf.maximum(0.0000001, 1. - disc_fake)))

# G Network Variables
gen_vars = [G.linear_w1, G.linear_b1, G.linear_w2, G.linear_b2, G.linear_w3, G.linear_b3]
# D Network Variables
disc_vars = [D.linear_w1, D.linear_b1, D.linear_w2, D.linear_b2]

# Create training operations !
train_gen = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(gan_class_loss, var_list=gen_vars)
train_disc = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(disc_loss, var_list=disc_vars)

################### Build The NN Attacker ####################
target_y = tf.placeholder(tf.float32, shape=[None, NUM_LABEL])
target_x = tf.placeholder(tf.float32, shape=[None, x_dim])
# aux_avai = 0
# if aux_avai:
#   nn_attac = NN_aux_attacker(NUM_LABEL)
#   nn_x = nn_attac(target_y, target_x)
# else:
nn_attac = NN_attacker(NUM_LABEL)
nn_x = nn_attac(target_y)

nn_y = model(nn_x)
nn_vars = [nn_attac.linear_w1, nn_attac.linear_b1, nn_attac.linear_w2, nn_attac.linear_b2, nn_attac.linear_w3, nn_attac.linear_b3]
nn_weights = tf.concat([tf.reshape(nn_attac.linear_w1,[1, -1]), tf.reshape(nn_attac.linear_b1,[1, -1]), tf.reshape(nn_attac.linear_w2,[1, -1]), tf.reshape(nn_attac.linear_b2,[1, -1]), tf.reshape(nn_attac.linear_w3,[1, -1]), tf.reshape(nn_attac.linear_b3,[1, -1])], 1)
nn_loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=target_y, logits=nn_y)) + 0.001 * tf.nn.l2_loss(nn_weights)
train_nn = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(nn_loss, var_list=nn_vars)

# Fredrickson Model Inversion Attack, Gradient Attack
def fred_mi(i, y_conv, sess, iterate, start_point):
  label_chosen = np.zeros(NUM_LABEL)
  label_chosen[i] = 1
  l2_lemda = 0.001
  cost_x = 1 - tf.squeeze(tf.gather(y_conv, i, axis=1), 0) + l2_lemda*tf.nn.l2_loss(x)
  gradient_of_cost = tf.gradients(cost_x, x)
  x_inv = x - tf.scalar_mul(LAMBDA, tf.squeeze(gradient_of_cost, 0))
  start_point = np.zeros((1, x_dim))
  x_mi = np.reshape(start_point,[1, x_dim])
  previous_costs = [inf,inf,inf,inf,inf]

  for i in range(ALPHA):
    x_mi = sess.run(x_inv, feed_dict={x: x_mi, y: [label_chosen] })
    cost_x_mi = sess.run(cost_x, feed_dict={x: x_mi, y: [label_chosen] })
    max_cost = max(previous_costs)
    
    if(cost_x_mi > max_cost or (iterate and cost_x_mi == 0)):
      print("Early break, no ALPHA HIT")
      break;
    else:
      previous_costs.append(cost_x_mi)
      previous_costs.pop(0)

    if(i % 1000 == 0):
      print('step %d, current cost is %g' % (i, cost_x_mi))

  print('iteration hit:', i+1)
#   check_pred = sess.run(correct, feed_dict={x: x_mi, y: [label_chosen] })
#   print("Prediction for reconstructed image:", check_pred)
  return x_mi

# %%
def train(beta, l2_coe):
  # Calculate MODEL Loss
  inv_loss = tf.losses.mean_squared_error(labels=x, predictions=inv_x)
  class_loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=y, logits=y_ml))
  model_loss = class_loss - beta * inv_loss + l2_coe*tf.nn.l2_loss(model_weights) #0.1
  y_pred = tf.argmax(y_ml, 1)
  correct = tf.equal(tf.argmax(y_ml, 1), tf.argmax(y, 1))
  accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

  # Build Optimizer !Use model_loss
  model_optimizer = tf.train.AdamOptimizer(0.001).minimize(model_loss, var_list=[model.linear_w1, model.linear_b1])#, model.linear_w2, model.linear_b2])
  inverter_optimizer = tf.train.GradientDescentOptimizer(0.001).minimize(inv_loss, var_list=[inverter.w_model, inverter.w_label, inverter.w_out, inverter.b_in, inverter.b_out])
  grad_model = tf.gradients(model_loss, [model.linear_w1, model.linear_b1])#, model.linear_w2, model.linear_b2])

  
  # Initialize the variables (i.e. assign their default value)
  init = tf.global_variables_initializer()

  # Start training
  with tf.Session() as sess:

      # Run the initializer
      sess.run(init)

      sess.run(iterator.initializer, feed_dict = {features: x_train, labels: y_train, batch_size: gan_batch_size, sample_size: 40000})

      # Train the Classifier First
      for i in range(8000):
        batch = sess.run(next_batch)
        model_optimizer.run(feed_dict={ x: batch[0], y: batch[1]})
        inverter_optimizer.run(feed_dict={ x: batch[0], y: batch[1]})
        if i % 500 == 0:
          gradients, train_accuracy = sess.run([grad_model, accuracy], feed_dict={x: batch[0], y: batch[1] })
#           print('gradients: ', gradients)
          print('Epoch %d, training accuracy %g' % (i, train_accuracy))    

      test_acc, y_prediction = sess.run([accuracy, y_pred], feed_dict={x: x_train, y: y_train})
      print("test acc:", test_acc)

#       cluster1 = []
#       cluster2 = []
#       cluster3 = []
#       for i in range(0, num_data*NUM_LABEL):
#         if y_prediction[i] == 0:
#           cluster1.append(x_train[i])
#         elif y_prediction[i] == 1:
#           cluster2.append(x_train[i])
#         else:
#           cluster3.append(x_train[i])

#       cluster1 = np.array(cluster1)
#       cluster2 = np.array(cluster2)
#       cluster3 = np.array(cluster3)
#       print('cluster1: ', cluster1.shape, 'cluster2: ', cluster2.shape, 'cluster3:', cluster3.shape)
#       plt.scatter(cluster1[:,0], cluster1[:,1],c='r')
#       plt.scatter(cluster2[:,0], cluster2[:,1],c='b')
#       plt.scatter(cluster3[:,0], cluster3[:,1],c='g')
#       plt.savefig('Classifier_plot')
#       plt.close()
      # Train Fredrickson MI
      inverted_x = np.zeros((NUM_LABEL, x_dim))
      for i in range(NUM_LABEL):
        print("i = %d" % i)
        inverted_x[i] = fred_mi(i, y_ml, sess, 1, aux_data[i*1000+800,:])[0]
      
      plt.scatter(inverted_x[:,0], inverted_x[:,1], marker='^', c='y')
      data_centers = np.stack((mu1, mu2, mu3),axis=0)
      dis = data_centers - inverted_x
      l2_dis = np.linalg.norm(dis,ord=2,axis=1)
      avg_dis = np.mean(l2_dis)
      return avg_dis, test_acc
      
      # Initialize Aux dataset for GAN train
#       aux_label = np.zeros([1000*NUM_LABEL, NUM_LABEL])
#       sess.run(iterator.initializer, feed_dict = {features: aux_data, labels: aux_label, batch_size: gan_batch_size, sample_size: 40000})
      
      #Train GAN
#       for i in range(50000):      
#         # Sample random noise 
#         batch = sess.run(next_batch)
#         z = np.random.uniform(-1., 1., size=[gan_batch_size, noise_dim])
#         #! Train Discriminator
# #         train_disc.run(feed_dict={aux_x: batch[0],  gen_input: z})
# #         if i % 5 == 0:
#         train_gen.run(feed_dict={aux_x: batch[0],  gen_input: z})
       
#         if i % 2000 == 0:
#           gl,dl,cl = sess.run([gen_loss, disc_loss, gan_class_loss], feed_dict={aux_x: batch[0],  gen_input: z})
#           print('Epoch %i: Generator Loss: %f, Discriminator Loss: %f, Classification loss: %f' % (i, gl, dl, cl))
          
#           plot_gan_image('gan_out',str(i), sess)
#           plt.scatter(inverted_x[:,0], inverted_x[:,1], marker='^', c='y')
      
      # Train neural net attacker
#       t_y = np.zeros([300,3])
#       t_y[0:100,0] = 1
#       t_y[101:200,1] = 1
#       t_y[201:300,2] = 1
#       for i in range(50000):      
#         batch = sess.run(next_batch)
# #         train_nn.run(feed_dict={target_x: batch[0], target_y:batch[1]})
#         train_nn.run(feed_dict={target_y:t_y})
#         if i % 2000 == 0:
# #           nl = sess.run(nn_loss, feed_dict={target_x: batch[0], target_y:batch[1]})
#           nl = sess.run(nn_loss, feed_dict={target_y:t_y})
#           print('Epoch %i: neural net loss:%f' % (i, nl))         
#           plot_nn_image('nn_out',str(i), sess)
#           plot_gan_image('gan_out',str(50000), sess)
#           plt.scatter(inverted_x[:,0], inverted_x[:,1], marker='^', c='y')
          
if __name__ == '__main__':
  beta = 0
  l2_coef = [0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1]
  distances = np.zeros(7)
  acc = np.zeros(7)
  i = 0
  for l2 in l2_coef:
    distances[i], acc[i] = train(beta, l2)
    
    i += 1
  
  plt.show()
  plt.plot(l2_coef, distances)
  plt.show()
  plt.plot(l2_coef, acc)
  plt.show()
# Out:
# Epoch 0, training accuracy 0.486667
# Epoch 500, training accuracy 0.546667
# Epoch 1000, training accuracy 1
# Epoch 1500, training accuracy 1
# Epoch 2000, training accuracy 1
# Epoch 2500, training accuracy 1
# Epoch 3000, training accuracy 1
# Epoch 3500, training accuracy 1
# Epoch 4000, training accuracy 1
# Epoch 4500, training accuracy 1
# Epoch 5000, training accuracy 1
# Epoch 5500, training accuracy 1
# Epoch 6000, training accuracy 1
# Epoch 6500, training accuracy 1
# Epoch 7000, training accuracy 1
# Epoch 7500, training accuracy 1
# test acc: 1.0
# i = 0
# step 0, current cost is 0.00181818
# step 1000, current cost is 0.0015948
# step 2000, current cost is 0.00144244
# step 3000, current cost is 0.0013358
# step 4000, current cost is 0.00125932
# step 5000, current cost is 0.00120368
# step 6000, current cost is 0.0011625
# step 7000, current cost is 0.00113188
# Early break, no ALPHA HIT
# iteration hit: 7445
# i = 1
# step 0, current cost is 0.999104
# step 1000, current cost is 0.998973
# step 2000, current cost is 0.998815
# step 3000, current cost is 0.998612
# step 4000, current cost is 0.998335
# step 5000, current cost is 0.997915
# step 6000, current cost is 0.99717
# step 7000, current cost is 0.995383
# step 8000, current cost is 0.984738
# step 9000, current cost is 0.0405775
# step 10000, current cost is 0.0356286
# step 11000, current cost is 0.0352522
# Early break, no ALPHA HIT
# iteration hit: 11818
# i = 2
# step 0, current cost is 0.999077
# step 1000, current cost is 0.998965
# step 2000, current cost is 0.998836
# step 3000, current cost is 0.998683
# step 4000, current cost is 0.998492
# step 5000, current cost is 0.998242
# step 6000, current cost is 0.997887
# step 7000, current cost is 0.997324
# step 8000, current cost is 0.996248
# step 9000, current cost is 0.993254
# step 10000, current cost is 0.950612
# step 11000, current cost is 0.0444413
# step 12000, current cost is 0.0417184
# step 13000, current cost is 0.0414327
# Early break, no ALPHA HIT
# iteration hit: 13816
# Epoch 0, training accuracy 0.486667
# Epoch 500, training accuracy 0.546667
# Epoch 1000, training accuracy 1
# Epoch 1500, training accuracy 1
# Epoch 2000, training accuracy 1
# Epoch 2500, training accuracy 1
# Epoch 3000, training accuracy 1
# Epoch 3500, training accuracy 1
# Epoch 4000, training accuracy 1
# Epoch 4500, training accuracy 1
# Epoch 5000, training accuracy 1
# Epoch 5500, training accuracy 1
# Epoch 6000, training accuracy 1
# Epoch 6500, training accuracy 1
# Epoch 7000, training accuracy 1
# Epoch 7500, training accuracy 1
# test acc: 1.0
# i = 0
# step 0, current cost is 0.00516367
# step 1000, current cost is 0.00396884
# step 2000, current cost is 0.00332827
# step 3000, current cost is 0.00295085
# step 4000, current cost is 0.00271478
# step 5000, current cost is 0.00256095
# step 6000, current cost is 0.0024578
# step 7000, current cost is 0.00238702
# step 8000, current cost is 0.00233767
# step 9000, current cost is 0.00230282
# step 10000, current cost is 0.0022781
# Early break, no ALPHA HIT
# iteration hit: 10634
# i = 1
# step 0, current cost is 0.997494
# step 1000, current cost is 0.996533
# step 2000, current cost is 0.994542
# step 3000, current cost is 0.986763
# step 4000, current cost is 0.0594094
# step 5000, current cost is 0.0388467
# step 6000, current cost is 0.0378641
# step 7000, current cost is 0.0377123
# Early break, no ALPHA HIT
# iteration hit: 7589
# i = 2
# step 0, current cost is 0.997339
# step 1000, current cost is 0.996503
# step 2000, current cost is 0.995038
# step 3000, current cost is 0.991445
# step 4000, current cost is 0.963515
# step 5000, current cost is 0.0514873
# step 6000, current cost is 0.0452903
# step 7000, current cost is 0.0446694
# step 8000, current cost is 0.0445574
# Early break, no ALPHA HIT
# iteration hit: 8763
# Epoch 0, training accuracy 0.486667
# Epoch 500, training accuracy 0.546667
# Epoch 1000, training accuracy 0.996667
# Epoch 1500, training accuracy 1
# Epoch 2000, training accuracy 1
# Epoch 2500, training accuracy 1
# Epoch 3000, training accuracy 1
# Epoch 3500, training accuracy 1
# Epoch 4000, training accuracy 1
# Epoch 4500, training accuracy 1
# Epoch 5000, training accuracy 1
# Epoch 5500, training accuracy 1
# Epoch 6000, training accuracy 1
# Epoch 6500, training accuracy 1
# Epoch 7000, training accuracy 1
# Epoch 7500, training accuracy 1
# test acc: 1.0
# i = 0
# step 0, current cost is 0.00992936
# step 1000, current cost is 0.00674752
# step 2000, current cost is 0.00536046
# step 3000, current cost is 0.00464026
# step 4000, current cost is 0.00422845
# step 5000, current cost is 0.0039781
# step 6000, current cost is 0.0038197
# step 7000, current cost is 0.00371638
# step 8000, current cost is 0.00364751
# step 9000, current cost is 0.00360091
# step 10000, current cost is 0.00356879
# step 11000, current cost is 0.00354655
# Early break, no ALPHA HIT
# iteration hit: 11459
# i = 1
# step 0, current cost is 0.995161
# step 1000, current cost is 0.991274
# step 2000, current cost is 0.959211
# step 3000, current cost is 0.0460687
# step 4000, current cost is 0.0404581
# step 5000, current cost is 0.0398475
# step 6000, current cost is 0.0397312
# Early break, no ALPHA HIT
# iteration hit: 6332
# i = 2
# step 0, current cost is 0.9949
# step 1000, current cost is 0.991746
# step 2000, current cost is 0.979381
# step 3000, current cost is 0.0810735
# step 4000, current cost is 0.0487614
# step 5000, current cost is 0.0470572
# step 6000, current cost is 0.0467677
# step 7000, current cost is 0.046703
# Early break, no ALPHA HIT
# iteration hit: 7482
# Epoch 0, training accuracy 0.486667
# Epoch 500, training accuracy 0.58
# Epoch 1000, training accuracy 0.996667
# Epoch 1500, training accuracy 1
# Epoch 2000, training accuracy 1
# Epoch 2500, training accuracy 1
# Epoch 3000, training accuracy 1
# Epoch 3500, training accuracy 1
# Epoch 4000, training accuracy 1
# Epoch 4500, training accuracy 1
# Epoch 5000, training accuracy 1
# Epoch 5500, training accuracy 1
# Epoch 6000, training accuracy 1
# Epoch 6500, training accuracy 1
# Epoch 7000, training accuracy 1
# Epoch 7500, training accuracy 1
# test acc: 1.0
# i = 0
# step 0, current cost is 0.0449978
# step 1000, current cost is 0.0205392
# step 2000, current cost is 0.0146559
# step 3000, current cost is 0.0123505
# step 4000, current cost is 0.0112508
# step 5000, current cost is 0.0106677
# step 6000, current cost is 0.010338
# step 7000, current cost is 0.0101432
# step 8000, current cost is 0.0100246
# step 9000, current cost is 0.00995078
# step 10000, current cost is 0.00990405
# Early break, no ALPHA HIT
# iteration hit: 10625
# i = 1
# step 0, current cost is 0.977635
# step 1000, current cost is 0.214678
# step 2000, current cost is 0.0510529
# step 3000, current cost is 0.0468599
# step 4000, current cost is 0.0461195
# step 5000, current cost is 0.0459353
# Early break, no ALPHA HIT
# iteration hit: 5949
# i = 2
# step 0, current cost is 0.977258
# step 1000, current cost is 0.638629
# step 2000, current cost is 0.0618694
# step 3000, current cost is 0.0544136
# step 4000, current cost is 0.0532095
# step 5000, current cost is 0.0529147
# step 6000, current cost is 0.0528299
# Early break, no ALPHA HIT
# iteration hit: 6643
# Epoch 0, training accuracy 0.486667
# Epoch 500, training accuracy 0.59
# Epoch 1000, training accuracy 0.996667
# Epoch 1500, training accuracy 1
# Epoch 2000, training accuracy 1
# Epoch 2500, training accuracy 1
# Epoch 3000, training accuracy 1
# Epoch 3500, training accuracy 1
# Epoch 4000, training accuracy 1
# Epoch 4500, training accuracy 1
# Epoch 5000, training accuracy 1
# Epoch 5500, training accuracy 1
# Epoch 6000, training accuracy 1
# Epoch 6500, training accuracy 1
# Epoch 7000, training accuracy 1
# Epoch 7500, training accuracy 1
# test acc: 0.99993336
# i = 0
# step 0, current cost is 0.0830268
# step 1000, current cost is 0.031578
# step 2000, current cost is 0.0218791
# step 3000, current cost is 0.0184266
# step 4000, current cost is 0.0168748
# step 5000, current cost is 0.0160887
# step 6000, current cost is 0.0156608
# step 7000, current cost is 0.0154167
# step 8000, current cost is 0.0152729
# step 9000, current cost is 0.0151863
# step 10000, current cost is 0.0151332
# step 11000, current cost is 0.0151001
# Early break, no ALPHA HIT
# iteration hit: 11405
# i = 1
# step 0, current cost is 0.9585
# step 1000, current cost is 0.103791
# step 2000, current cost is 0.0539034
# step 3000, current cost is 0.0501331
# step 4000, current cost is 0.0493323
# step 5000, current cost is 0.049109
# step 6000, current cost is 0.0490388
# Early break, no ALPHA HIT
# iteration hit: 6454
# i = 2
# step 0, current cost is 0.958196
# step 1000, current cost is 0.165384
# step 2000, current cost is 0.0632232
# step 3000, current cost is 0.0574564
# step 4000, current cost is 0.0562786
# step 5000, current cost is 0.0559519
# step 6000, current cost is 0.0558484
# Early break, no ALPHA HIT
# iteration hit: 6963
# Epoch 0, training accuracy 0.486667
# Epoch 500, training accuracy 0.56
# Epoch 1000, training accuracy 0.996667
# Epoch 1500, training accuracy 0.99
# Epoch 2000, training accuracy 1
# Epoch 2500, training accuracy 1
# Epoch 3000, training accuracy 0.99
# Epoch 3500, training accuracy 0.99
# Epoch 4000, training accuracy 0.99
# Epoch 4500, training accuracy 0.99
# Epoch 5000, training accuracy 1
# Epoch 5500, training accuracy 0.993333
# Epoch 6000, training accuracy 0.993333
# Epoch 6500, training accuracy 0.996667
# Epoch 7000, training accuracy 0.996667
# Epoch 7500, training accuracy 0.993333
# test acc: 0.99583334
# i = 0
# step 0, current cost is 0.285796
# step 1000, current cost is 0.0831064
# step 2000, current cost is 0.0543865
# step 3000, current cost is 0.0458082
# step 4000, current cost is 0.0423671
# step 5000, current cost is 0.0407717
# step 6000, current cost is 0.0399676
# step 7000, current cost is 0.0395405
# step 8000, current cost is 0.0393055
# step 9000, current cost is 0.0391729
# step 10000, current cost is 0.0390965
# step 11000, current cost is 0.0390523
# Early break, no ALPHA HIT
# iteration hit: 11518
# i = 1
# step 0, current cost is 0.85613
# step 1000, current cost is 0.107207
# step 2000, current cost is 0.0654888
# step 3000, current cost is 0.0594878
# step 4000, current cost is 0.0578617
# step 5000, current cost is 0.0573116
# step 6000, current cost is 0.0571044
# step 7000, current cost is 0.0570215
# step 8000, current cost is 0.056987
# Early break, no ALPHA HIT
# iteration hit: 8029
# i = 2
# step 0, current cost is 0.856792
# step 1000, current cost is 0.130194
# step 2000, current cost is 0.0739384
# step 3000, current cost is 0.0661723
# step 4000, current cost is 0.0640834
# step 5000, current cost is 0.0633742
# step 6000, current cost is 0.0631046
# step 7000, current cost is 0.0629956
# step 8000, current cost is 0.0629496
# step 9000, current cost is 0.0629298
# Early break, no ALPHA HIT
# iteration hit: 9226
# Epoch 0, training accuracy 0.486667
# Epoch 500, training accuracy 0.533333
# Epoch 1000, training accuracy 0.97
# Epoch 1500, training accuracy 0.976667
# Epoch 2000, training accuracy 0.986667
# Epoch 2500, training accuracy 0.963333
# Epoch 3000, training accuracy 0.973333
# Epoch 3500, training accuracy 0.97
# Epoch 4000, training accuracy 0.973333
# Epoch 4500, training accuracy 0.976667
# Epoch 5000, training accuracy 0.983333
# Epoch 5500, training accuracy 0.96
# Epoch 6000, training accuracy 0.97
# Epoch 6500, training accuracy 0.98
# Epoch 7000, training accuracy 0.97
# Epoch 7500, training accuracy 0.97
# test acc: 0.97606665
# i = 0
# step 0, current cost is 0.422246
# step 1000, current cost is 0.130292
# step 2000, current cost is 0.0817839
# step 3000, current cost is 0.0680607
# step 4000, current cost is 0.0627831
# step 5000, current cost is 0.0604152
# step 6000, current cost is 0.0592546
# step 7000, current cost is 0.058653
# step 8000, current cost is 0.0583296
# step 9000, current cost is 0.0581511
# step 10000, current cost is 0.058051
# step 11000, current cost is 0.0579939
# step 12000, current cost is 0.057961
# Early break, no ALPHA HIT
# iteration hit: 12048
# i = 1
# step 0, current cost is 0.787434
# step 1000, current cost is 0.122924
# step 2000, current cost is 0.0733762
# step 3000, current cost is 0.0651215
# step 4000, current cost is 0.0627076
# step 5000, current cost is 0.0618328
# step 6000, current cost is 0.0614793
# step 7000, current cost is 0.061327
# step 8000, current cost is 0.0612586
# step 9000, current cost is 0.0612266
# Early break, no ALPHA HIT
# iteration hit: 9158
# i = 2
# step 0, current cost is 0.788669
# step 1000, current cost is 0.142772
# step 2000, current cost is 0.0814188
# step 3000, current cost is 0.0712924
# step 4000, current cost is 0.068332
# step 5000, current cost is 0.0672532
# step 6000, current cost is 0.0668134
# step 7000, current cost is 0.0666216
# step 8000, current cost is 0.0665341
# step 9000, current cost is 0.0664927
# Early break, no ALPHA HIT
# iteration hit: 9957
