# %% [markdown]
# <a href="https://colab.research.google.com/github/fuyan2/ML_research/blob/master/Fred_vs_GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random
import math
inf = math.inf

tf.reset_default_graph()
tf.set_random_seed(1)

# Training Params
num_steps = 100000
learning_rate = 0.00002
x_dim = 2
noise_dim = 20
NUM_LABEL = 3
GAN_CLASS_COE = 10
gan_batch_size = 100*NUM_LABEL
num_data = 10000
INV_HIDDEN = 100
beta = 0.5 #1
lemda = 0.0001

#Fredrickson Params
ALPHA = 50000
BETA = 5
GAMMA = 1
LAMBDA = 0.06

# A custom initialization (see Xavier Glorot init)
def glorot_init(shape):
    return tf.random_normal(shape=shape, stddev=1. / tf.sqrt(shape[0] / 2.), dtype=tf.float32)
 
# Linear Regression 
class Generator(object):
  # G Parameters
  def __init__(self, noise_dim, NUM_LABEL, batch_size):
    self.batch_size = batch_size
    self.linear_w1 = tf.Variable(glorot_init([noise_dim+NUM_LABEL, 100]),name='glw1')
    self.linear_b1 = tf.Variable(tf.zeros([100]),name='glb1')
    self.linear_w2 = tf.Variable(glorot_init([100, 50]),name='glw2')
    self.linear_b2 = tf.Variable(tf.zeros([50]),name='glb2')
    self.linear_w3 = tf.Variable(glorot_init([50, x_dim]),name='glw3')
    self.linear_b3 = tf.Variable(tf.zeros([x_dim]),name='glb3')
    
    self.training = True

 # Build G Graph
  def __call__(self, z,y):
    z_y = tf.concat((z,y),1)
    linear_z1 = tf.nn.leaky_relu(tf.matmul(z_y,self.linear_w1) + self.linear_b1)
    linear_z2 = tf.nn.leaky_relu(tf.matmul(linear_z1,self.linear_w2) + self.linear_b2)
    out_layer = tf.matmul(linear_z2,self.linear_w3)+self.linear_b3
    return out_layer

# Logistic Regression
class Disciminator(object):
  # D Parameters
  def __init__(self):
    self.linear_w1 = tf.Variable(glorot_init([x_dim + NUM_LABEL, 100]))
    self.linear_b1 = tf.Variable(tf.zeros([100]))
    self.linear_w2 = tf.Variable(glorot_init([100, 1]))
    self.linear_b2 = tf.Variable(tf.zeros([1]))

    self.training = True

  # Build D Graph
  def __call__(self, x, y):
    x_y = tf.concat((x,y),1)
    linear1 = tf.nn.relu(tf.matmul(x_y, self.linear_w1) + self.linear_b1)
    out = tf.matmul(linear1, self.linear_w2) + self.linear_b2
    out = tf.sigmoid(out)
    return out

class Classifier(object):
  def __init__(self):
    self.linear_w1 = tf.Variable(glorot_init([x_dim, NUM_LABEL]))
    self.linear_b1 = tf.Variable(tf.zeros([NUM_LABEL]))
#     self.linear_w2 = tf.Variable(glorot_init([1, NUM_LABEL]))
#     self.linear_b2 = tf.Variable(tf.zeros([NUM_LABEL]))

    self.training = True

  # Build D Graph
  def __call__(self, x):
#     linear1 = tf.nn.relu(tf.matmul(x, self.linear_w1) + self.linear_b1)
#     out = tf.nn.softmax(tf.matmul(linear1, self.linear_w2) + self.linear_b2)
    out = tf.nn.softmax(tf.matmul(x, self.linear_w1) + self.linear_b1)
    return out
  
def lrelu(x, alpha):
  return tf.nn.relu(x) - alpha * tf.nn.relu(-x)

class Inverter_Regularizer(object):
  def __init__(self, weight_shape):
    self.w_model =  tf.Variable(glorot_init([weight_shape, INV_HIDDEN]))
    self.w_label = tf.Variable(glorot_init([NUM_LABEL, INV_HIDDEN]))
    self.w_out = tf.Variable(glorot_init([INV_HIDDEN, x_dim]))
    self.b_in = tf.Variable(tf.zeros([INV_HIDDEN]))
    self.b_out = tf.Variable(tf.zeros([x_dim]))
    
  def __call__(self, y, model_weights):
    # Input Layer
    ww = tf.matmul(model_weights, self.w_model)
    wy = tf.matmul(y, self.w_label)
    wt = tf.add(wy, ww)
    hidden_layer =  tf.add(wt, self.b_in)
    rect = lrelu(hidden_layer, 0.3)
    # Output Layer
    out_layer = tf.add(tf.matmul(rect, self.w_out), self.b_out)
    rect = lrelu(out_layer, 0.3)
    return rect
  
def plot_gan_image(name, epoch, sess):
  # Generate images from noise, using the generator network.
  fig, ax = plt.subplots()
  for i in range(NUM_LABEL):   
    # Desired label
    d_label = np.zeros([gan_batch_size, NUM_LABEL])
    d_label[:, i] = 1
    # Noise input.
    z = np.random.uniform(-1., 1., size=[gan_batch_size, noise_dim])
    g = sess.run([gen_sample], feed_dict={gen_input: z, desired_label: d_label})
    g = np.reshape(g, [gan_batch_size,2])
    if i == 0:
      ax.scatter(g[:,0], g[:,1], c='r')
    elif i == 1:
      ax.scatter(g[:,0], g[:,1], c='b')
    elif i == 2:
      ax.scatter(g[:,0], g[:,1], c='g')
      
  plt.savefig(name+epoch)

###################### Build Dataset #############################
features = tf.placeholder(tf.float32, shape=[None, x_dim])
labels = tf.placeholder(tf.float32, shape=[None, NUM_LABEL])
batch_size = tf.placeholder(tf.int64)
sample_size = tf.placeholder(tf.int64)
dataset = tf.data.Dataset.from_tensor_slices((features, labels))
dataset = dataset.shuffle(sample_size, reshuffle_each_iteration=True)
dataset = dataset.batch(batch_size, drop_remainder=True).repeat()
iterator = dataset.make_initializable_iterator()
next_batch = iterator.get_next()

mu1 = [0., 0.]
sigma1 = [[1., 0.], [0., 1.]]
mu2 = [10., 0.]
sigma2 = [[1., 0.], [0., 1.]]
mu3 = [5., 10.]
x_1 = np.random.multivariate_normal(mu1, sigma1, num_data)
x_2 = np.random.multivariate_normal(mu2, sigma1, num_data)
x_3 = np.random.multivariate_normal(mu3, sigma1, num_data)

plt.scatter(x_1[:,0], x_1[:,1], c='r')
plt.scatter(x_2[:,0], x_2[:,1], c='b')
plt.scatter(x_3[:,0], x_3[:,1], c='g')

# !label=3
x_train = np.concatenate((x_1, x_2, x_3), axis=0)
y_train = np.zeros([num_data*NUM_LABEL, NUM_LABEL])
for i in range(NUM_LABEL):
  y_train[i*num_data:(i+1)*num_data, i] = 1.
  
#aux_data is same as data1
aux_mu1 = [0., 0.]
aux_mu2 = [10., 0.]
aux_mu3 = [5., 10.]

aux_data1 = np.random.multivariate_normal(aux_mu1, sigma1, 1000)
aux_data2 = np.random.multivariate_normal(aux_mu2, sigma1, 1000)
aux_data3 = np.random.multivariate_normal(aux_mu3, sigma1, 1000)

aux_data = np.concatenate((aux_data1, aux_data2, aux_data3), axis=0)
# random.shuffle(aux_data)
plt.scatter(aux_data[:,0], aux_data[:,1], c='y')


################### Build The Classifier ####################
x = tf.placeholder(tf.float32, shape=[None, x_dim])
y = tf.placeholder(tf.float32, shape=[None, NUM_LABEL])
model = Classifier()
y_ml = model(x)
# Build Inverter Regularizer
model_weights = tf.concat([tf.reshape(model.linear_w1,[1, -1]),tf.reshape(model.linear_b1,[1, -1])] ,1) #, tf.reshape(model.linear_w2,[1, -1]), tf.reshape(model.linear_b2,[1, -1])], 1)
weight_shape = int(model_weights.shape[1])
inverter = Inverter_Regularizer(weight_shape)
inv_x = inverter(y, model_weights)

# Calculate MODEL Loss
inv_loss = tf.losses.mean_squared_error(labels=x, predictions=inv_x)
class_loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=y, logits=y_ml))
model_loss = class_loss - beta * inv_loss + lemda*tf.nn.l2_loss(model_weights)
y_pred = tf.argmax(y_ml, 1)
correct = tf.equal(tf.argmax(y_ml, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# Build Optimizer !Use model_loss
model_optimizer = tf.train.AdamOptimizer(0.001).minimize(model_loss, var_list=[model.linear_w1, model.linear_b1])#, model.linear_w2, model.linear_b2])
inverter_optimizer = tf.train.GradientDescentOptimizer(0.001).minimize(inv_loss, var_list=[inverter.w_model, inverter.w_label, inverter.w_out, inverter.b_in, inverter.b_out])
grad_model = tf.gradients(class_loss, [model.linear_w1, model.linear_b1])#, model.linear_w2, model.linear_b2])

#################### Build GAN Networks ############################
# Network Inputs
gen_input = tf.placeholder(tf.float32, shape=[None, noise_dim], name='input_noise')
aux_x = tf.placeholder(tf.float32, shape=[None, x_dim])
aux_label = model(aux_x)
desired_label = tf.one_hot(tf.argmax(aux_label, 1), NUM_LABEL) 

# Build G Network
G = Generator(noise_dim, NUM_LABEL, gan_batch_size)
gen_sample = G(gen_input,desired_label)
gen_label =  model(gen_sample)

# Build 2 D Networks (one from noise input, one from generated samples)
D = Disciminator()
disc_real = D(aux_x, desired_label)
disc_fake = D(gen_sample, desired_label)

# Build Loss
gen_weights = tf.concat([tf.reshape(G.linear_w1,[1, -1]),tf.reshape(G.linear_b1,[1, -1]), tf.reshape(G.linear_w2,[1, -1]), tf.reshape(G.linear_b2,[1, -1]), tf.reshape(G.linear_w3,[1, -1]), tf.reshape(G.linear_b3,[1, -1])], 1)
gan_class_loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=desired_label, logits=gen_label)) + 0.007 * tf.nn.l2_loss(gen_weights)
gen_loss = -tf.reduce_mean(tf.log(tf.maximum(0.00001, disc_fake))) + GAN_CLASS_COE*gan_class_loss
disc_loss = -tf.reduce_mean(tf.log(tf.maximum(0.0000001, disc_real)) + tf.log(tf.maximum(0.0000001, 1. - disc_fake)))

# G Network Variables
gen_vars = [G.linear_w1, G.linear_b1, G.linear_w2, G.linear_b2, G.linear_w3, G.linear_b3]
# D Network Variables
disc_vars = [D.linear_w1, D.linear_b1, D.linear_w2, D.linear_b2]

# Create training operations !
train_gen = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(gan_class_loss, var_list=gen_vars)
train_disc = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(disc_loss, var_list=disc_vars)

# Fredrickson Model Inversion Attack, Gradient Attack

def fred_mi(i, y_conv, sess, iterate):
  label_chosen = np.zeros(NUM_LABEL)
  label_chosen[i] = 1
  
  cost_x = 1 - tf.squeeze(tf.gather(y_conv, i, axis=1), 0)
  gradient_of_cost = tf.gradients(cost_x, x)
  x_inv = x - tf.scalar_mul(LAMBDA, tf.squeeze(gradient_of_cost, 0))
  x_mi = np.zeros((1, x_dim))
  previous_costs = [inf,inf,inf,inf,inf]

  for i in range(ALPHA):
    x_mi = sess.run(x_inv, feed_dict={x: x_mi, y: [label_chosen] })
    cost_x_mi = sess.run(cost_x, feed_dict={x: x_mi, y: [label_chosen] })
    max_cost = max(previous_costs)
    
    if(cost_x_mi > max_cost or (iterate and cost_x_mi == 0)):
      print("Early break, no ALPHA HIT")
      break;
    else:
      previous_costs.append(cost_x_mi)
      previous_costs.pop(0)

    if(i % 1000 == 0):
      print('step %d, current cost is %g' % (i, cost_x_mi))

  print('iteration hit:', i+1)
  check_pred = sess.run(correct, feed_dict={x: x_mi, y: [label_chosen] })
  print("Prediction for reconstructed image:", check_pred)
  return x_mi

# %%
def train_gan():
  # Train Classifier
  
  # Initialize the variables (i.e. assign their default value)
  init = tf.global_variables_initializer()

  # Start training
  with tf.Session() as sess:

      # Run the initializer
      sess.run(init)

      sess.run(iterator.initializer, feed_dict = {features: x_train, labels: y_train, batch_size: gan_batch_size, sample_size: 40000})

      # Train the Classifier First
      for i in range(4000):
        batch = sess.run(next_batch)
        model_optimizer.run(feed_dict={ x: batch[0], y: batch[1]})
        inverter_optimizer.run(feed_dict={ x: batch[0], y: batch[1]})
        if i % 500 == 0:
          gradients, train_accuracy = sess.run([grad_model, accuracy], feed_dict={x: batch[0], y: batch[1] })
#           print('gradients: ', gradients)
          print('Epoch %d, training accuracy %g' % (i, train_accuracy))    

      test_acc, y_prediction = sess.run([accuracy, y_pred], feed_dict={x: x_train, y: y_train})
      print("test acc:", test_acc)

      cluster1 = []
      cluster2 = []
      cluster3 = []
      for i in range(0, num_data*NUM_LABEL):
        if y_prediction[i] == 0:
          cluster1.append(x_train[i])
        elif y_prediction[i] == 1:
          cluster2.append(x_train[i])
        else:
          cluster3.append(x_train[i])

      cluster1 = np.array(cluster1)
      cluster2 = np.array(cluster2)
      cluster3 = np.array(cluster3)
      print('cluster1: ', cluster1.shape, 'cluster2: ', cluster2.shape, 'cluster3:', cluster3.shape)
      plt.scatter(cluster1[:,0], cluster1[:,1],c='r')
      plt.scatter(cluster2[:,0], cluster2[:,1],c='b')
      plt.scatter(cluster3[:,0], cluster3[:,1],c='g')
      plt.savefig('Classifier_plot')
      
      # Train Fredrickson MI
      inverted_x = np.zeros((NUM_LABEL, x_dim))
      for i in range(NUM_LABEL):
        print("i = %d" % i)
        inverted_x[i] = fred_mi(i, y_ml, sess, 1)[0]
      
      plt.scatter(inverted_x[:,0], inverted_x[:,1], marker='^', c='y')

      # Initialize Aux dataset for GAN train
      aux_label = np.zeros([1000*NUM_LABEL, NUM_LABEL])
      sess.run(iterator.initializer, feed_dict = {features: aux_data, labels: aux_label, batch_size: gan_batch_size, sample_size: 40000})
      
      #Train GAN
      for i in range(50000):      
        # Sample random noise 
        batch = sess.run(next_batch)
        z = np.random.uniform(-1., 1., size=[gan_batch_size, noise_dim])
        #! Train Discriminator
#         train_disc.run(feed_dict={aux_x: batch[0],  gen_input: z})
#         if i % 5 == 0:
        train_gen.run(feed_dict={aux_x: batch[0],  gen_input: z})
       
        if i % 2000 == 0:
          gl,dl,cl = sess.run([gen_loss, disc_loss, gan_class_loss], feed_dict={aux_x: batch[0],  gen_input: z})
          print('Epoch %i: Generator Loss: %f, Discriminator Loss: %f, Classification loss: %f' % (i, gl, dl, cl))
          
          plot_gan_image('gan_out',str(i), sess)
          plt.scatter(inverted_x[:,0], inverted_x[:,1], marker='^', c='y')
      

        
if __name__ == '__main__':
  train_gan()
# Out:
# Epoch 0, training accuracy 0.516667
# Epoch 500, training accuracy 0.483333
# Epoch 1000, training accuracy 0.553333
# Epoch 1500, training accuracy 0.62
# Epoch 2000, training accuracy 0.646667
# Epoch 2500, training accuracy 0.676667
# Epoch 3000, training accuracy 1
# Epoch 3500, training accuracy 1
# test acc: 0.99983335
# cluster1:  (9995, 2) cluster2:  (10003, 2) cluster3: (10002, 2)
# i = 0
# step 0, current cost is 0.0524281
# step 1000, current cost is 0.0214668
# step 2000, current cost is 0.0133524
# step 3000, current cost is 0.00966287
# step 4000, current cost is 0.00756222
# step 5000, current cost is 0.00620836
# step 6000, current cost is 0.00526398
# step 7000, current cost is 0.0045681
# step 8000, current cost is 0.00403404
# step 9000, current cost is 0.00361145
# step 10000, current cost is 0.00326884
# step 11000, current cost is 0.00298548
# step 12000, current cost is 0.00274712
# step 13000, current cost is 0.00254411
# step 14000, current cost is 0.00236881
# step 15000, current cost is 0.00221604
# step 16000, current cost is 0.00208193
# step 17000, current cost is 0.00196296
# step 18000, current cost is 0.0018568
# step 19000, current cost is 0.00176167
# step 20000, current cost is 0.00167567
# step 21000, current cost is 0.0015977
# step 22000, current cost is 0.00152665
# step 23000, current cost is 0.00146163
# step 24000, current cost is 0.00140184
# step 25000, current cost is 0.00134695
# step 26000, current cost is 0.00129604
# step 27000, current cost is 0.00124896
# step 28000, current cost is 0.00120509
# step 29000, current cost is 0.00116402
# step 30000, current cost is 0.00112599
# step 31000, current cost is 0.00109005
# step 32000, current cost is 0.00105661
# step 33000, current cost is 0.00102496
# step 34000, current cost is 0.000995219
# step 35000, current cost is 0.000967145
# step 36000, current cost is 0.000940621
# step 37000, current cost is 0.000915527
# step 38000, current cost is 0.000891745
# step 39000, current cost is 0.000869095
# step 40000, current cost is 0.000847578
# step 41000, current cost is 0.000827253
# step 42000, current cost is 0.000807703
# step 43000, current cost is 0.000789046
# step 44000, current cost is 0.000771284
# step 45000, current cost is 0.000754356
# step 46000, current cost is 0.000738204
# step 47000, current cost is 0.000722587
# step 48000, current cost is 0.000707626
# step 49000, current cost is 0.000693321
# iteration hit: 50000
# Prediction for reconstructed image: [ True]
# i = 1
# step 0, current cost is 0.96978
# step 1000, current cost is 0.135004
# step 2000, current cost is 0.0192642
# step 3000, current cost is 0.0100726
# step 4000, current cost is 0.00679612
# step 5000, current cost is 0.00512248
# step 6000, current cost is 0.00410867
# step 7000, current cost is 0.0034287
# step 8000, current cost is 0.00294161
# step 9000, current cost is 0.00257552
# step 10000, current cost is 0.00229037
# step 11000, current cost is 0.0020619
# step 12000, current cost is 0.00187486
# step 13000, current cost is 0.00171876
# step 14000, current cost is 0.00158691
# step 15000, current cost is 0.00147367
# step 16000, current cost is 0.00137544
# step 17000, current cost is 0.00128949
# step 18000, current cost is 0.00121373
# step 19000, current cost is 0.00114632
# step 20000, current cost is 0.00108612
# step 21000, current cost is 0.00103176
# step 22000, current cost is 0.000982642
# step 23000, current cost is 0.000937998
# step 24000, current cost is 0.000897169
# step 25000, current cost is 0.000859737
# step 26000, current cost is 0.000825465
# step 27000, current cost is 0.000793636
# step 28000, current cost is 0.000764251
# step 29000, current cost is 0.000737011
# step 30000, current cost is 0.00071156
# step 31000, current cost is 0.000687957
# step 32000, current cost is 0.000665724
# step 33000, current cost is 0.000644863
# step 34000, current cost is 0.000625193
# step 35000, current cost is 0.000607014
# step 36000, current cost is 0.000589609
# step 37000, current cost is 0.000573158
# step 38000, current cost is 0.000557721
# step 39000, current cost is 0.000543177
# step 40000, current cost is 0.00052911
# step 41000, current cost is 0.000515938
# step 42000, current cost is 0.000503302
# step 43000, current cost is 0.000491381
# step 44000, current cost is 0.000479817
# step 45000, current cost is 0.000469089
# step 46000, current cost is 0.000458598
# step 47000, current cost is 0.000448644
# step 48000, current cost is 0.000439107
# step 49000, current cost is 0.000429928
# iteration hit: 50000
# Prediction for reconstructed image: [ True]
# i = 2
# step 0, current cost is 0.977653
# step 1000, current cost is 0.51316
# step 2000, current cost is 0.0226315
# step 3000, current cost is 0.010703
# step 4000, current cost is 0.00697798
# step 5000, current cost is 0.00516993
# step 6000, current cost is 0.0041039
# step 7000, current cost is 0.00340146
# step 8000, current cost is 0.00290394
# step 9000, current cost is 0.0025332
# step 10000, current cost is 0.0022462
# step 11000, current cost is 0.00201762
# step 12000, current cost is 0.00183117
# step 13000, current cost is 0.00167614
# step 14000, current cost is 0.00154543
# step 15000, current cost is 0.00143343
# step 16000, current cost is 0.00133669
# step 17000, current cost is 0.00125217
# step 18000, current cost is 0.00117761
# step 19000, current cost is 0.00111157
# step 20000, current cost is 0.00105244
# step 21000, current cost is 0.000999272
# step 22000, current cost is 0.000951231
# step 23000, current cost is 0.00090766
# step 24000, current cost is 0.000867784
# step 25000, current cost is 0.000831366
# step 26000, current cost is 0.000797808
# step 27000, current cost is 0.000766873
# step 28000, current cost is 0.000738323
# step 29000, current cost is 0.000711739
# step 30000, current cost is 0.000687003
# step 31000, current cost is 0.000663936
# step 32000, current cost is 0.000642359
# step 33000, current cost is 0.000622272
# step 34000, current cost is 0.000603199
# step 35000, current cost is 0.000585318
# step 36000, current cost is 0.000568569
# step 37000, current cost is 0.000552714
# step 38000, current cost is 0.000537574
# step 39000, current cost is 0.000523388
# step 40000, current cost is 0.000509977
# step 41000, current cost is 0.000497103
# step 42000, current cost is 0.000484943
# step 43000, current cost is 0.000473261
# step 44000, current cost is 0.000462294
# step 45000, current cost is 0.000451744
# step 46000, current cost is 0.000441611
# step 47000, current cost is 0.000431955
# step 48000, current cost is 0.000422776
# step 49000, current cost is 0.000413835
# iteration hit: 50000
# Prediction for reconstructed image: [ True]
# Epoch 0: Generator Loss: 23.114855, Discriminator Loss: 1.216887, Classification loss: 2.261111
# Epoch 2000: Generator Loss: 17.135542, Discriminator Loss: 3.068700, Classification loss: 1.703389
# Epoch 4000: Generator Loss: 13.790762, Discriminator Loss: 3.200537, Classification loss: 1.358348
# Epoch 6000: Generator Loss: 12.050483, Discriminator Loss: 2.902411, Classification loss: 1.179079
# Epoch 8000: Generator Loss: 10.676547, Discriminator Loss: 2.971257, Classification loss: 1.039485
# Epoch 10000: Generator Loss: 9.616921, Discriminator Loss: 3.049955, Classification loss: 0.936047
# Epoch 12000: Generator Loss: 8.829887, Discriminator Loss: 3.159469, Classification loss: 0.858145
# Epoch 14000: Generator Loss: 8.260182, Discriminator Loss: 3.422296, Classification loss: 0.802112
# Epoch 16000: Generator Loss: 7.874409, Discriminator Loss: 3.186532, Classification loss: 0.760795
# Epoch 18000: Generator Loss: 7.572927, Discriminator Loss: 3.127926, Classification loss: 0.730233
# Epoch 20000: Generator Loss: 7.315178, Discriminator Loss: 3.369509, Classification loss: 0.707157
# Epoch 22000: Generator Loss: 7.144369, Discriminator Loss: 3.242833, Classification loss: 0.689893
# Epoch 24000: Generator Loss: 7.039114, Discriminator Loss: 3.041589, Classification loss: 0.677557
# Epoch 26000: Generator Loss: 6.932472, Discriminator Loss: 3.224729, Classification loss: 0.667982
# Epoch 28000: Generator Loss: 6.857966, Discriminator Loss: 3.253473, Classification loss: 0.661289
# Epoch 30000: Generator Loss: 6.810451, Discriminator Loss: 3.344163, Classification loss: 0.656551
# Epoch 32000: Generator Loss: 6.798893, Discriminator Loss: 3.070762, Classification loss: 0.653462
# Epoch 34000: Generator Loss: 6.753592, Discriminator Loss: 3.176230, Classification loss: 0.650670
# Epoch 36000: Generator Loss: 6.721143, Discriminator Loss: 3.317950, Classification loss: 0.648675
# Epoch 38000: Generator Loss: 6.728410, Discriminator Loss: 3.249079, Classification loss: 0.647962
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Epoch 40000: Generator Loss: 6.711663, Discriminator Loss: 3.171025, Classification loss: 0.646950
# Epoch 42000: Generator Loss: 6.688450, Discriminator Loss: 3.342206, Classification loss: 0.646102
# Epoch 44000: Generator Loss: 6.734242, Discriminator Loss: 3.161113, Classification loss: 0.646852
# Epoch 46000: Generator Loss: 6.704369, Discriminator Loss: 3.362130, Classification loss: 0.646124
# Epoch 48000: Generator Loss: 6.703544, Discriminator Loss: 3.270110, Classification loss: 0.645980
