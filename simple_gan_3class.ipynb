# %% [markdown]
# <a href="https://colab.research.google.com/github/fuyan2/ML_research/blob/master/simple_gan_3class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import division, print_function, absolute_import

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random

tf.reset_default_graph()
tf.set_random_seed(1)

# Training Params
num_steps = 100000
learning_rate = 0.00002
x_dim = 2
noise_dim = 20
NUM_LABEL = 3
GAN_CLASS_COE = 500
gan_batch_size = 500*NUM_LABEL
num_data = 10000
INV_HIDDEN = 100
beta = 0.001
# A custom initialization (see Xavier Glorot init)
def glorot_init(shape):
    return tf.random_normal(shape=shape, stddev=1. / tf.sqrt(shape[0] / 2.), dtype=tf.float32)
 
# Linear Regression 
class Generator(object):
  # G Parameters
  def __init__(self, noise_dim, NUM_LABEL, batch_size):
    self.batch_size = batch_size
    self.linear_w1 = tf.Variable(glorot_init([noise_dim+NUM_LABEL, 100]),name='glw1')
    self.linear_b1 = tf.Variable(glorot_init([100]),name='glb1')
    self.linear_w2 = tf.Variable(glorot_init([100, 50]),name='glw2')
    self.linear_b2 = tf.Variable(glorot_init([50]),name='glb2')
    self.linear_w3 = tf.Variable(glorot_init([50, x_dim]),name='glw3')
    self.linear_b3 = tf.Variable(glorot_init([x_dim]),name='glb3')
    
    self.training = True

 # Build G Graph
  def __call__(self, z,y):
    z_y = tf.concat((z,y),1)
    linear_z1 = tf.nn.leaky_relu(tf.matmul(z_y,self.linear_w1) + self.linear_b1)
    linear_z2 = tf.nn.leaky_relu(tf.matmul(linear_z1,self.linear_w2) + self.linear_b2)
    out_layer = tf.matmul(linear_z2,self.linear_w3)+self.linear_b3
    return out_layer

# Logistic Regression
class Disciminator(object):
  # D Parameters
  def __init__(self):
    self.linear_w1 = tf.Variable(glorot_init([x_dim + NUM_LABEL, 100]))
    self.linear_b1 = tf.Variable(glorot_init([100]))
    self.linear_w2 = tf.Variable(glorot_init([100, 1]))
    self.linear_b2 = tf.Variable(glorot_init([1]))

    self.training = True

  # Build D Graph
  def __call__(self, x, y):
    x_y = tf.concat((x,y),1)
    linear1 = tf.nn.leaky_relu(tf.matmul(x_y, self.linear_w1) + self.linear_b1)
    out = tf.matmul(linear1, self.linear_w2) + self.linear_b2
    out = tf.sigmoid(out)
    return out

class Classifier(object):
  def __init__(self):
    self.linear_w1 = tf.Variable(glorot_init([x_dim, NUM_LABEL]))
    self.linear_b1 = tf.Variable(glorot_init([NUM_LABEL]))
#     self.linear_w2 = tf.Variable(glorot_init([100, NUM_LABEL]))
#     self.linear_b2 = tf.Variable(glorot_init([NUM_LABEL]))

    self.training = True

  # Build D Graph
  def __call__(self, x):
    out = tf.matmul(x, self.linear_w1) + self.linear_b1
#     out = tf.matmul(linear1, self.linear_w2) + self.linear_b2
    out = tf.nn.softmax(out)
    return out
  
def lrelu(x, alpha):
  return tf.nn.relu(x) - alpha * tf.nn.relu(-x)

def inverter(y, model_weights):
  # Input layer
  ww = tf.matmul(model_weights, inv_weights['w_model'])
  wy = tf.matmul(y, inv_weights['w_label'])
  wt = tf.add(wy, ww)
  hidden_layer =  tf.add(wt, inv_weights['b_in'])
  rect = lrelu(hidden_layer, 0.3)
  # Output Layer
  out_layer = tf.add(tf.matmul(rect, inv_weights['w_out']), inv_weights['b_out'])
  rect = lrelu(out_layer, 0.3)
  return rect

def plot_gan_image(name, epoch, sess):
  # Generate images from noise, using the generator network.
  fig, ax = plt.subplots()
  for i in range(NUM_LABEL):   
    # Desired label
    d_label = np.zeros([gan_batch_size, NUM_LABEL])
    d_label[:] = i
    # Noise input.
    z = np.random.uniform(-1., 1., size=[gan_batch_size, noise_dim])
    g = sess.run([gen_sample], feed_dict={gen_input: z, desired_label: d_label})
    g = np.reshape(g, [gan_batch_size,2])
    if i == 0:
      ax.scatter(g[:,0], g[:,1], c='r')
    elif i == 1:
      ax.scatter(g[:,0], g[:,1], c='b')
    elif i == 2:
      ax.scatter(g[:,0], g[:,1], c='g')
     
  # f.show()
  plt.savefig(name+epoch)

###################### Build Dataset #############################
features = tf.placeholder(tf.float32, shape=[None, x_dim])
labels = tf.placeholder(tf.float32, shape=[None, NUM_LABEL])
batch_size = tf.placeholder(tf.int64)
sample_size = tf.placeholder(tf.int64)
dataset = tf.data.Dataset.from_tensor_slices((features, labels))
dataset = dataset.shuffle(sample_size, reshuffle_each_iteration=True)
dataset = dataset.batch(batch_size, drop_remainder=True).repeat()
iter = dataset.make_initializable_iterator()
next_batch = iter.get_next()

mu1 = [0., 0.]
sigma1 = [[1., 0.], [0., 1.]]
mu2 = [50., 0.]
sigma2 = [[1., 0.], [0., 1.]]
mu3 = [25., 50.]
x_1 = np.random.multivariate_normal(mu1, sigma1, num_data)
x_2 = np.random.multivariate_normal(mu2, sigma1, num_data)
x_3 = np.random.multivariate_normal(mu3, sigma1, num_data)

plt.scatter(x_1[:,0], x_1[:,1], c='r')
plt.scatter(x_2[:,0], x_2[:,1], c='b')
plt.scatter(x_3[:,0], x_3[:,1], c='g')

# !label=3
x_train = np.concatenate((x_1, x_2, x_3), axis=0)
y_train = np.zeros([num_data*NUM_LABEL, NUM_LABEL])
for i in range(NUM_LABEL):
  y_train[i*num_data:(i+1)*num_data, i] = 1.
  
#aux_data is same as data1
aux_mu1 = [0., 0.]
aux_mu2 = [50., 0.]
aux_mu3 = [0., 0.]

aux_data1 = np.random.multivariate_normal(mu1, sigma1, 500)
aux_data2 = np.random.multivariate_normal(mu2, sigma1, 500)
aux_data3 = np.random.multivariate_normal(mu3, sigma1, 500)

aux_data = np.concatenate((aux_data1, aux_data2, aux_data3), axis=0)
# random.shuffle(aux_data)
plt.scatter(aux_data[:,0], aux_data[:,1], c='y')


################### Build The Classifier ####################
x = tf.placeholder(tf.float32, shape=[None, x_dim])
y = tf.placeholder(tf.float32, shape=[None, NUM_LABEL])
model = Classifier()
y_ml = model(x)
# Build Inverter Regularizer
model_weights = tf.concat([tf.reshape(model.linear_w1,[1, -1]),tf.reshape(model.linear_b1,[1, -1])], 1)
inv_weights = {
  'w_model': tf.get_variable("w_model",[tf.reshape(model_weights, [-1]).shape[0], INV_HIDDEN]),
  'w_label': tf.get_variable("w_label",[NUM_LABEL, INV_HIDDEN]),
  'w_out': tf.get_variable("w_out",[INV_HIDDEN, x_dim]),
  'b_in': tf.Variable(tf.zeros([INV_HIDDEN])),
  'b_out': tf.Variable(tf.zeros([x_dim]))
}

inv_x = inverter(y, model_weights)

# Calculate loss
inv_loss = tf.losses.mean_squared_error(labels=x, predictions=inv_x)
class_loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=y, logits=y_ml))
model_loss = class_loss - beta * inv_loss
y_pred = tf.argmax(y_ml, 1)
correct = tf.equal(tf.argmax(y_ml, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# Build Optimizer !Use model_loss
model_optimizer = tf.train.AdamOptimizer(0.001).minimize(class_loss, var_list=[model.linear_w1, model.linear_b1])
inverter_optimizer = tf.train.GradientDescentOptimizer(0.001).minimize(inv_loss)

#################### Build GAN Networks ############################
# Network Inputs
gen_input = tf.placeholder(tf.float32, shape=[None, noise_dim], name='input_noise')
aux_x = tf.placeholder(tf.float32, shape=[None, x_dim])
aux_label = model(aux_x)
desired_label = tf.one_hot(tf.argmax(aux_label, 1), NUM_LABEL) 

# Build G Network
G = Generator(noise_dim, NUM_LABEL, gan_batch_size)
gen_sample = G(gen_input,desired_label)
gen_label =  model(gen_sample)

# Build 2 D Networks (one from noise input, one from generated samples)
D = Disciminator()
disc_real = D(aux_x, desired_label)
disc_fake = D(gen_sample, desired_label)

# Build Loss
gan_class_loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=desired_label, logits=gen_label))
# gen_loss = -tf.reduce_mean(tf.log(tf.maximum(0.01, disc_fake))) + GAN_CLASS_COE*gan_class_loss
# disc_loss = -tf.reduce_mean(tf.log(tf.maximum(0.01, disc_real)) + tf.log(tf.maximum(0.01, 1. - disc_fake)))

gen_loss = -tf.reduce_mean(tf.log(disc_fake)) + GAN_CLASS_COE*gan_class_loss
disc_loss = -tf.reduce_mean(tf.log(disc_real) + tf.log(1. - disc_fake))

# G Network Variables
gen_vars = [G.linear_w1, G.linear_b1, G.linear_w2, G.linear_b2, G.linear_w3, G.linear_b3]
# D Network Variables
disc_vars = [D.linear_w1, D.linear_b1, D.linear_w2, D.linear_b2]

# Create training operations
train_gen = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(gen_loss, var_list=gen_vars)
train_disc = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(disc_loss, var_list=disc_vars)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/dataset_ops.py:1419: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/losses/losses_impl.py:667: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
def train_gan():
  # Train Classifier
  
  # Initialize the variables (i.e. assign their default value)
  init = tf.global_variables_initializer()

  # Start training
  with tf.Session() as sess:

      # Run the initializer
      sess.run(init)

      sess.run(iter.initializer, feed_dict = {features: x_train, labels: y_train, batch_size: gan_batch_size, sample_size: 40000})

      # Train the Classifier First
      for i in range(4000):
        batch = sess.run(next_batch)
        model_optimizer.run(feed_dict={ x: batch[0], y: batch[1]})
#         inverter_optimizer.run(feed_dict={ x: batch[0], y: batch[1]})
        if i % 500 == 0:
          train_accuracy = accuracy.eval(feed_dict={x: batch[0], y: batch[1] })
          print('Epoch %d, training accuracy %g' % (i, train_accuracy))    

      test_acc, y_prediction,y_prop = sess.run([accuracy, y_pred, y_ml], feed_dict={x: x_train, y: y_train})
      print("test acc:", test_acc)

      cluster1 = []
      cluster2 = []
      cluster3 = []
      for i in range(0, num_data*NUM_LABEL):
        if y_prediction[i] == 0:
          cluster1.append(x_train[i])
        elif y_prediction[i] == 1:
          cluster2.append(x_train[i])
        else:
          cluster3.append(x_train[i])

      cluster1 = np.array(cluster1)
      cluster2 = np.array(cluster2)
      cluster3 = np.array(cluster3)
      print('cluster1: ', cluster1.shape, 'cluster2: ', cluster2.shape, 'cluster3:', cluster3.shape)
      plt.scatter(cluster1[:,0], cluster1[:,1],c='r')
      plt.scatter(cluster2[:,0], cluster2[:,1],c='b')
      plt.scatter(cluster3[:,0], cluster3[:,1],c='g')
      plt.savefig('Classifier_plot')
      
      #Train GAN
      for i in range(200000):      
        # Sample random noise 
        z = np.random.uniform(-1., 1., size=[gan_batch_size, noise_dim])
       
        #! Train Discriminator
        train_disc.run(feed_dict={aux_x: aux_data,  gen_input: z})
#         if i % 5 == 0:
        train_gen.run(feed_dict={aux_x: aux_data,  gen_input: z})
       
        if i % 2000 == 0:
          gl,dl = sess.run([gen_loss, disc_loss], feed_dict={aux_x: aux_data,  gen_input: z})
          print('Epoch %i: Generator Loss: %f, Discriminator Loss: %f' % (i, gl, dl))
          plot_gan_image('gan_out',str(i), sess)
      
      
if __name__ == '__main__':
  train_gan()
# Out:
# Epoch 0, training accuracy 0.436
# Epoch 500, training accuracy 0.51
# Epoch 1000, training accuracy 0.659333
# Epoch 1500, training accuracy 1
# Epoch 2000, training accuracy 1
# Epoch 2500, training accuracy 1
# Epoch 3000, training accuracy 1
# Epoch 3500, training accuracy 1
# test acc: 1.0
# cluster1:  (10000, 2) cluster2:  (10000, 2) cluster3: (10000, 2)
# Epoch 0: Generator Loss: 605.869507, Discriminator Loss: 2.327986
# Epoch 2000: Generator Loss: 516.194153, Discriminator Loss: 0.577174
# Epoch 4000: Generator Loss: 449.571777, Discriminator Loss: 0.298994
# Epoch 6000: Generator Loss: 435.151459, Discriminator Loss: 0.645712
# Epoch 8000: Generator Loss: 336.579163, Discriminator Loss: 0.479503
# Epoch 10000: Generator Loss: 288.231567, Discriminator Loss: 0.251639
# Epoch 12000: Generator Loss: 281.976654, Discriminator Loss: 0.273663
# Epoch 14000: Generator Loss: 279.390259, Discriminator Loss: 0.940118
# Epoch 16000: Generator Loss: 279.153961, Discriminator Loss: 0.963357
# Epoch 18000: Generator Loss: 278.975403, Discriminator Loss: 1.105204
# Epoch 20000: Generator Loss: 278.798248, Discriminator Loss: 1.280628
# Epoch 22000: Generator Loss: 278.687286, Discriminator Loss: 1.375336
# Epoch 24000: Generator Loss: 278.639862, Discriminator Loss: 1.394095
# Epoch 26000: Generator Loss: 278.612701, Discriminator Loss: 1.372283
# Epoch 28000: Generator Loss: 278.601349, Discriminator Loss: 1.314476
# Epoch 30000: Generator Loss: 278.569000, Discriminator Loss: 1.270996
# Epoch 32000: Generator Loss: 278.542023, Discriminator Loss: 1.272564
# Epoch 34000: Generator Loss: 278.545807, Discriminator Loss: 1.245268
# Epoch 36000: Generator Loss: 278.609161, Discriminator Loss: 1.328922
# Epoch 38000: Generator Loss: 278.539734, Discriminator Loss: 1.232056
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Epoch 40000: Generator Loss: 278.592834, Discriminator Loss: 1.268821
# Epoch 42000: Generator Loss: 278.532623, Discriminator Loss: 1.206892
# Epoch 44000: Generator Loss: 278.518127, Discriminator Loss: 1.210224
# Epoch 46000: Generator Loss: 278.557343, Discriminator Loss: 1.288562
# Epoch 48000: Generator Loss: 278.640533, Discriminator Loss: 1.394660
# Epoch 50000: Generator Loss: 278.403870, Discriminator Loss: 1.135531
# Epoch 52000: Generator Loss: 278.697845, Discriminator Loss: 1.391545
# Epoch 54000: Generator Loss: 278.425995, Discriminator Loss: 1.128320
# Epoch 56000: Generator Loss: 278.709106, Discriminator Loss: 1.346644
# Epoch 58000: Generator Loss: 278.450043, Discriminator Loss: 1.186442
# Epoch 60000: Generator Loss: 278.586487, Discriminator Loss: 1.198996
# Epoch 62000: Generator Loss: 278.540771, Discriminator Loss: 1.252186
# Epoch 64000: Generator Loss: 278.382629, Discriminator Loss: 1.121002
# Epoch 66000: Generator Loss: 278.545349, Discriminator Loss: 1.214333
# Epoch 68000: Generator Loss: 278.611115, Discriminator Loss: 1.246948
# Epoch 70000: Generator Loss: 278.533752, Discriminator Loss: 1.238229
# Epoch 72000: Generator Loss: 278.450195, Discriminator Loss: 1.115633
# Epoch 74000: Generator Loss: 278.591309, Discriminator Loss: 1.335879
# Epoch 76000: Generator Loss: 278.335663, Discriminator Loss: 1.101281
# Epoch 78000: Generator Loss: 278.667450, Discriminator Loss: 1.410358
# Epoch 80000: Generator Loss: 278.360107, Discriminator Loss: 1.119125
# Epoch 82000: Generator Loss: 278.601685, Discriminator Loss: 1.322237
# Epoch 84000: Generator Loss: 278.309723, Discriminator Loss: 1.099910
# Epoch 86000: Generator Loss: 278.582458, Discriminator Loss: 1.255025
# Epoch 88000: Generator Loss: 278.637177, Discriminator Loss: 1.346433
# Epoch 90000: Generator Loss: 278.321594, Discriminator Loss: 1.102382
# Epoch 92000: Generator Loss: 278.684235, Discriminator Loss: 1.396335
# Epoch 94000: Generator Loss: 278.328400, Discriminator Loss: 1.108656
# Epoch 96000: Generator Loss: 278.686188, Discriminator Loss: 1.403808
# Epoch 98000: Generator Loss: 278.400299, Discriminator Loss: 1.152807
# Epoch 100000: Generator Loss: 278.680145, Discriminator Loss: 1.384212
# Epoch 102000: Generator Loss: 278.509491, Discriminator Loss: 1.209989
# Epoch 104000: Generator Loss: 278.740997, Discriminator Loss: 1.392818
# Epoch 106000: Generator Loss: 278.315735, Discriminator Loss: 1.114183
# Epoch 108000: Generator Loss: 278.709473, Discriminator Loss: 1.433889
# Epoch 110000: Generator Loss: 278.322418, Discriminator Loss: 1.091277
# Epoch 112000: Generator Loss: 278.626251, Discriminator Loss: 1.325497
# Epoch 114000: Generator Loss: 278.303406, Discriminator Loss: 1.145720
# Epoch 116000: Generator Loss: 278.714813, Discriminator Loss: 1.491501
# Epoch 118000: Generator Loss: 278.264099, Discriminator Loss: 1.113628
# Epoch 120000: Generator Loss: 278.607269, Discriminator Loss: 1.317533
# Epoch 122000: Generator Loss: 278.371887, Discriminator Loss: 1.119981
# Epoch 124000: Generator Loss: 278.560577, Discriminator Loss: 1.202453
# Epoch 126000: Generator Loss: 278.414917, Discriminator Loss: 1.146551
# Epoch 128000: Generator Loss: 278.514496, Discriminator Loss: 1.211553
# Epoch 130000: Generator Loss: 278.451508, Discriminator Loss: 1.177316
# Epoch 132000: Generator Loss: 278.514465, Discriminator Loss: 1.198204
# Epoch 134000: Generator Loss: 278.265076, Discriminator Loss: 1.117791
# Epoch 136000: Generator Loss: 278.461578, Discriminator Loss: 1.202795
# Epoch 138000: Generator Loss: 278.801544, Discriminator Loss: 1.472167
# Epoch 140000: Generator Loss: 278.313507, Discriminator Loss: 1.107789
# Epoch 142000: Generator Loss: 278.683319, Discriminator Loss: 1.402281
# Epoch 144000: Generator Loss: 278.529755, Discriminator Loss: 1.217611
# Epoch 146000: Generator Loss: 278.714905, Discriminator Loss: 1.387389
# Epoch 148000: Generator Loss: 278.455383, Discriminator Loss: 1.185624
# Epoch 150000: Generator Loss: 278.762543, Discriminator Loss: 1.412568
# Epoch 152000: Generator Loss: 278.418671, Discriminator Loss: 1.145584
# Epoch 154000: Generator Loss: 278.687897, Discriminator Loss: 1.293859
# Epoch 156000: Generator Loss: 278.535675, Discriminator Loss: 1.250968
# Epoch 158000: Generator Loss: 278.324158, Discriminator Loss: 1.121395
# Epoch 160000: Generator Loss: 278.692230, Discriminator Loss: 1.454718
# Epoch 162000: Generator Loss: 278.237091, Discriminator Loss: 1.102650
# Epoch 164000: Generator Loss: 278.585052, Discriminator Loss: 1.287020
# Epoch 166000: Generator Loss: 278.449768, Discriminator Loss: 1.140849
# Epoch 168000: Generator Loss: 278.756134, Discriminator Loss: 1.447658
# Epoch 170000: Generator Loss: 278.330658, Discriminator Loss: 1.089291
# Epoch 172000: Generator Loss: 278.671875, Discriminator Loss: 1.383443
# Epoch 174000: Generator Loss: 278.503876, Discriminator Loss: 1.218359
# Epoch 176000: Generator Loss: 278.818848, Discriminator Loss: 1.461311
# Epoch 178000: Generator Loss: 278.227692, Discriminator Loss: 1.100349
# Epoch 180000: Generator Loss: 278.642700, Discriminator Loss: 1.378877
# Epoch 182000: Generator Loss: 278.438110, Discriminator Loss: 1.141252
# Epoch 184000: Generator Loss: 278.745911, Discriminator Loss: 1.475321
# Epoch 186000: Generator Loss: 278.419769, Discriminator Loss: 1.131160
# Epoch 188000: Generator Loss: 278.468262, Discriminator Loss: 1.154083
# Epoch 190000: Generator Loss: 278.591583, Discriminator Loss: 1.280666
# Epoch 192000: Generator Loss: 278.398743, Discriminator Loss: 1.125998
# Epoch 194000: Generator Loss: 278.758331, Discriminator Loss: 1.510173
# Epoch 196000: Generator Loss: 278.231750, Discriminator Loss: 1.089593
# Epoch 198000: Generator Loss: 278.606506, Discriminator Loss: 1.268357
