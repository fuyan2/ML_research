# %% [markdown]
# <a href="https://colab.research.google.com/github/fuyan2/ML_research/blob/master/simple_gan_classifier_as_discriminator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import division, print_function, absolute_import

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random

tf.reset_default_graph()
tf.set_random_seed(1)

# Training Params
num_steps = 100000
learning_rate = 0.00001
x_dim = 2
noise_dim = 20
NUM_LABEL = 3
GAN_CLASS_COE = 500
gan_batch_size = GAN_CLASS_COE*NUM_LABEL
num_data = 10000
# A custom initialization (see Xavier Glorot init)
def glorot_init(shape):
    return tf.random_normal(shape=shape, stddev=1. / tf.sqrt(shape[0] / 2.), dtype=tf.float32)
 
# Linear Regression 
class Generator(object):
  # G Parameters
  def __init__(self, noise_dim, NUM_LABEL, batch_size):
    self.batch_size = batch_size
    self.linear_w1 = tf.Variable(glorot_init([noise_dim+NUM_LABEL, 100]),name='glw1')
    self.linear_b1 = tf.Variable(glorot_init([100]),name='glb1')
    self.linear_w2 = tf.Variable(glorot_init([100, 50]),name='glw2')
    self.linear_b2 = tf.Variable(glorot_init([50]),name='glb2')
    self.linear_w3 = tf.Variable(glorot_init([50, x_dim]),name='glw3')
    self.linear_b3 = tf.Variable(glorot_init([x_dim]),name='glb3')
    
    self.training = True

 # Build G Graph
  def __call__(self, z,y):
    z_y = tf.concat((z,y),1)
    linear_z1 = tf.nn.leaky_relu(tf.matmul(z_y,self.linear_w1) + self.linear_b1)
    linear_z2 = tf.nn.leaky_relu(tf.matmul(linear_z1,self.linear_w2) + self.linear_b2)
    out_layer = tf.matmul(linear_z2,self.linear_w3)+self.linear_b3
    return out_layer

# Logistic Regression
class Disciminator(object):
  # D Parameters
  def __init__(self):
    self.linear_w1 = tf.Variable(glorot_init([x_dim + NUM_LABEL, 100]))
    self.linear_b1 = tf.Variable(glorot_init([100]))
    self.linear_w2 = tf.Variable(glorot_init([100, 1]))
    self.linear_b2 = tf.Variable(glorot_init([1]))

    self.training = True

  # Build D Graph
  def __call__(self, x, y):
    x_y = tf.concat((x,y),1)
    linear1 = tf.nn.leaky_relu(tf.matmul(x_y, self.linear_w1) + self.linear_b1)
    out = tf.matmul(linear1, self.linear_w2) + self.linear_b2
    out = tf.sigmoid(out)
    return out

class Classifier(object):
  def __init__(self):
    self.linear_w1 = tf.Variable(glorot_init([x_dim, NUM_LABEL]))
    self.linear_b1 = tf.Variable(glorot_init([NUM_LABEL]))
#     self.linear_w2 = tf.Variable(glorot_init([100, NUM_LABEL]))
#     self.linear_b2 = tf.Variable(glorot_init([NUM_LABEL]))

    self.training = True

  # Build D Graph
  def __call__(self, x):
    out = tf.matmul(x, self.linear_w1) + self.linear_b1
#     out = tf.matmul(linear1, self.linear_w2) + self.linear_b2
    out = tf.nn.softmax(out)
    return out
  
  
def plot_gan_image(name, epoch, sess):
  # Generate images from noise, using the generator network.
  fig, ax = plt.subplots()
  for i in range(NUM_LABEL):   
    # Desired label
    d_label = np.zeros([gan_batch_size, NUM_LABEL])
    d_label[:] = i
    # Noise input.
    z = np.random.uniform(-1., 1., size=[gan_batch_size, noise_dim])
    g = sess.run([gen_sample], feed_dict={gen_input: z, desired_label: d_label})
    g = np.reshape(g, [gan_batch_size,2])
    if i == 0:
      ax.scatter(g[:,0], g[:,1], c='r')
    elif i == 1:
      ax.scatter(g[:,0], g[:,1], c='b')
    elif i == 2:
      ax.scatter(g[:,0], g[:,1], c='g')
     
  # f.show()
  plt.savefig(name+epoch)

# Build Dataset
features = tf.placeholder(tf.float32, shape=[None, x_dim])
labels = tf.placeholder(tf.float32, shape=[None, NUM_LABEL])
batch_size = tf.placeholder(tf.int64)
sample_size = tf.placeholder(tf.int64)
dataset = tf.data.Dataset.from_tensor_slices((features, labels))
dataset = dataset.shuffle(sample_size, reshuffle_each_iteration=True)
dataset = dataset.batch(batch_size, drop_remainder=True).repeat()
iter = dataset.make_initializable_iterator()
next_batch = iter.get_next()

mu1 = [0., 0.]
sigma1 = [[1., 0.], [0., 1.]]
mu2 = [100., 0.]
sigma2 = [[1., 0.], [0., 1.]]
mu3 = [50., 100.]
x_1 = np.random.multivariate_normal(mu1, sigma1, num_data)
x_2 = np.random.multivariate_normal(mu2, sigma1, num_data)
x_3 = np.random.multivariate_normal(mu3, sigma1, num_data)

plt.scatter(x_1[:,0], x_1[:,1], c='r')
plt.scatter(x_2[:,0], x_2[:,1], c='b')
plt.scatter(x_3[:,0], x_3[:,1], c='g')

x_train = np.concatenate((x_1, x_2, x_3), axis=0)
y_train = np.zeros([num_data*NUM_LABEL, NUM_LABEL])
for i in range(NUM_LABEL):
  y_train[i*num_data:(i+1)*num_data, i] = 1.
  
#aux_data is same as data1
aux_mu1 = [0., 0.]
aux_mu2 = [50., 0.]
aux_mu3 = [0., 0.]

aux_data1 = np.random.multivariate_normal(mu1, sigma1, 500)
aux_data2 = np.random.multivariate_normal(mu2, sigma1, 500)
aux_data3 = np.random.multivariate_normal(mu3, sigma1, 500)

aux_data = np.concatenate((aux_data1, aux_data2, aux_data3), axis=0)
# random.shuffle(aux_data)
plt.scatter(aux_data[:,0], aux_data[:,1], c='y')


# Build The Classifier
x = tf.placeholder(tf.float32, shape=[None, x_dim])
y = tf.placeholder(tf.float32, shape=[None, NUM_LABEL])
model = Classifier()
y_ml = model(x)
model_loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=y, logits=y_ml))

y_pred = tf.argmax(y_ml, 1)
correct = tf.equal(tf.argmax(y_ml, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

model_optimizer = tf.train.AdamOptimizer(0.001).minimize(model_loss, var_list=[model.linear_w1, model.linear_b1])

# Build Networks
# Network Inputs
gen_input = tf.placeholder(tf.float32, shape=[None, noise_dim], name='input_noise')
# aux_x = tf.placeholder(tf.float32, shape=[None, x_dim])
# aux_label = model(aux_x)
# desired_label = tf.one_hot(tf.argmax(aux_label, 1), NUM_LABEL) 

###### USE MODEL AS DISCRIMINATOR #######
desired_label = tf.placeholder(tf.float32, shape=[None, NUM_LABEL])
########

# Build G Network
G = Generator(noise_dim, NUM_LABEL, gan_batch_size)
gen_sample = G(gen_input,desired_label)
gen_label =  model(gen_sample)

# # Build 2 D Networks (one from noise input, one from generated samples)
# D = Disciminator()
# disc_real = D(aux_x, aux_label)
# disc_fake = D(gen_sample, gen_label)

# # Build Loss
gan_class_loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=desired_label, logits=gen_label))

# gen_loss = -tf.reduce_mean(tf.log(tf.maximum(0.1, disc_fake))) + GAN_CLASS_COE*gan_class_loss
# disc_loss = -tf.reduce_mean(tf.log(tf.maximum(0.1, disc_real)) + tf.log(tf.maximum(0.1, 1. - disc_fake)))

# # gen_loss = -tf.reduce_mean(disc_fake) + GAN_CLASS_COE*gan_class_loss
# # disc_loss = -tf.reduce_mean(disc_real) + tf.reduce_mean(disc_fake) 

# # Build Optimizers
optimizer_gen = tf.train.AdamOptimizer(learning_rate=learning_rate)
# optimizer_disc = tf.train.AdamOptimizer(learning_rate=learning_rate)

# # G Network Variables
gen_vars = [G.linear_w1, G.linear_b1, G.linear_w2, G.linear_b2, G.linear_w3, G.linear_b3]
# # D Network Variables
# disc_vars = [D.linear_w1, D.linear_b1, D.linear_w2, D.linear_b2]

# # Create training operations
# train_gen = optimizer_gen.minimize(gen_loss, var_list=gen_vars)
train_gen = optimizer_gen.minimize(gan_class_loss, var_list=gen_vars)
# train_disc = optimizer_disc.minimize(disc_loss, var_list=disc_vars)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/dataset_ops.py:1419: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
def train_gan():
  # Train Classifier
  
  # Initialize the variables (i.e. assign their default value)
  init = tf.global_variables_initializer()

  # Start training
  with tf.Session() as sess:

      # Run the initializer
      sess.run(init)

      sess.run(iter.initializer, feed_dict = {features: x_train, labels: y_train, batch_size: gan_batch_size, sample_size: 40000})

      # Train the Classifier First
      for i in range(3000):
        batch = sess.run(next_batch)
        model_optimizer.run(feed_dict={ x: batch[0], y: batch[1]})
        if i % 500 == 0:
          train_accuracy = accuracy.eval(feed_dict={x: batch[0], y: batch[1] })
          print('Epoch %d, training accuracy %g' % (i, train_accuracy))    

      test_acc, y_prediction,y_prop = sess.run([accuracy, y_pred, y_ml], feed_dict={x: x_train, y: y_train})
      print("test acc:", test_acc)

      cluster1 = []
      cluster2 = []
      cluster3 = []
      for i in range(0, num_data*NUM_LABEL):
        if y_prediction[i] == 0:
          cluster1.append(x_train[i])
        elif y_prediction[i] == 1:
          cluster2.append(x_train[i])
        else:
          cluster3.append(x_train[i])

      cluster1 = np.array(cluster1)
      cluster2 = np.array(cluster2)
      cluster3 = np.array(cluster3)
      print('cluster1: ', cluster1.shape, 'cluster2: ', cluster2.shape, 'cluster3:', cluster3.shape)
      plt.scatter(cluster1[:,0], cluster1[:,1],c='r')
      plt.scatter(cluster2[:,0], cluster2[:,1],c='b')
      plt.scatter(cluster3[:,0], cluster3[:,1],c='g')
      plt.savefig('Classifier_plot')
      
      #Train GAN
      for i in range(1000000):
        batch_x = aux_data
        
        # Sample random noise 
        z = np.random.uniform(-1., 1., size=[gan_batch_size, noise_dim])
       
        desired = np.zeros([gan_batch_size, NUM_LABEL])
        for j in range(NUM_LABEL):
          desired[j*500:(j+1)*500, j] = 1.
          
        #! Train Discriminator
#         train_disc.run(feed_dict={desired_label: desired,  gen_input: z})
#         if i % 5 == 0:
        train_gen.run(feed_dict={desired_label: desired,  gen_input: z})
       
        if i % 2000 == 0:
          gl = sess.run(gan_class_loss, feed_dict={desired_label: desired,  gen_input: z})
          print('Epoch %i: Generator Loss: %f' % (i, gl))
          plot_gan_image('gan_out',str(i), sess)
      
      
if __name__ == '__main__':
  train_gan()
# Out:
# Epoch 0, training accuracy 0.426667
# Epoch 500, training accuracy 0.516667
# Epoch 1000, training accuracy 0.659333
# Epoch 1500, training accuracy 1
# Epoch 2000, training accuracy 1
# Epoch 2500, training accuracy 1
# test acc: 1.0
# cluster1:  (10000, 2) cluster2:  (10000, 2) cluster3: (10000, 2)
# Epoch 0: Generator Loss: 1.204477
# Epoch 2000: Generator Loss: 1.194506
# Epoch 4000: Generator Loss: 1.149552
# Epoch 6000: Generator Loss: 1.042978
# Epoch 8000: Generator Loss: 0.962108
# Epoch 10000: Generator Loss: 0.919036
# Epoch 12000: Generator Loss: 0.891321
# Epoch 14000: Generator Loss: 0.875196
# Epoch 16000: Generator Loss: 0.865619
# Epoch 18000: Generator Loss: 0.860672
# Epoch 20000: Generator Loss: 0.858126
# Epoch 22000: Generator Loss: 0.856491
# Epoch 24000: Generator Loss: 0.855512
# Epoch 26000: Generator Loss: 0.854935
# Epoch 28000: Generator Loss: 0.854619
# Epoch 30000: Generator Loss: 0.854369
# Epoch 32000: Generator Loss: 0.854199
# Epoch 34000: Generator Loss: 0.854097
# Epoch 36000: Generator Loss: 0.854044
# Epoch 38000: Generator Loss: 0.853988
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Epoch 40000: Generator Loss: 0.853923
# Epoch 42000: Generator Loss: 0.853880
# Epoch 44000: Generator Loss: 0.853827
# Epoch 46000: Generator Loss: 0.853730
# Epoch 48000: Generator Loss: 0.853007
# Epoch 50000: Generator Loss: 0.843626
# Epoch 52000: Generator Loss: 0.760528
# Epoch 54000: Generator Loss: 0.640011
# Epoch 56000: Generator Loss: 0.581183
# Epoch 58000: Generator Loss: 0.563553
# Epoch 60000: Generator Loss: 0.556669
# Epoch 62000: Generator Loss: 0.553662
# Epoch 64000: Generator Loss: 0.552397
# Epoch 66000: Generator Loss: 0.551838
# Epoch 68000: Generator Loss: 0.551605
# Epoch 70000: Generator Loss: 0.551509
# Epoch 72000: Generator Loss: 0.551471
# Epoch 74000: Generator Loss: 0.551455
# Epoch 76000: Generator Loss: 0.551449
# Epoch 78000: Generator Loss: 0.551446
# Epoch 80000: Generator Loss: 0.551445
# Epoch 82000: Generator Loss: 0.551445
# Epoch 84000: Generator Loss: 0.551445
# Epoch 86000: Generator Loss: 0.551445
# Epoch 88000: Generator Loss: 0.551445
# Epoch 90000: Generator Loss: 0.551445
# Epoch 92000: Generator Loss: 0.551445
# Epoch 94000: Generator Loss: 0.551445
# Epoch 96000: Generator Loss: 0.551445
# Epoch 98000: Generator Loss: 0.551445
# Epoch 100000: Generator Loss: 0.551445
# Epoch 102000: Generator Loss: 0.551445
# Epoch 104000: Generator Loss: 0.551445
# Epoch 106000: Generator Loss: 0.551445
# Epoch 108000: Generator Loss: 0.551445
# Epoch 110000: Generator Loss: 0.551445
# Epoch 112000: Generator Loss: 0.551445
# Epoch 114000: Generator Loss: 0.551445
# Epoch 116000: Generator Loss: 0.551445
# Epoch 118000: Generator Loss: 0.551445
# Epoch 120000: Generator Loss: 0.551445
# Epoch 122000: Generator Loss: 0.551445
# Epoch 124000: Generator Loss: 0.551445
# Epoch 126000: Generator Loss: 0.551445
# Epoch 128000: Generator Loss: 0.551445
# Epoch 130000: Generator Loss: 0.551445
# Epoch 132000: Generator Loss: 0.551445
# Epoch 134000: Generator Loss: 0.551445
# Epoch 136000: Generator Loss: 0.551445
# Epoch 138000: Generator Loss: 0.551445
# Epoch 140000: Generator Loss: 0.551445
# Epoch 142000: Generator Loss: 0.551445
# Epoch 144000: Generator Loss: 0.551445
# Epoch 146000: Generator Loss: 0.551445
# Epoch 148000: Generator Loss: 0.551445
# Epoch 150000: Generator Loss: 0.551445
# Epoch 152000: Generator Loss: 0.551445
# Epoch 154000: Generator Loss: 0.551445
# Epoch 156000: Generator Loss: 0.551445
# Epoch 158000: Generator Loss: 0.551445
# Epoch 160000: Generator Loss: 0.551445
# Epoch 162000: Generator Loss: 0.551445
# Epoch 164000: Generator Loss: 0.551445
# Epoch 166000: Generator Loss: 0.551445
# Epoch 168000: Generator Loss: 0.551445
# Epoch 170000: Generator Loss: 0.551445
# Epoch 172000: Generator Loss: 0.551445
# Epoch 174000: Generator Loss: 0.551445
# Epoch 176000: Generator Loss: 0.551445
# Epoch 178000: Generator Loss: 0.551445
# Epoch 180000: Generator Loss: 0.551445
# Epoch 182000: Generator Loss: 0.551445
# Epoch 184000: Generator Loss: 0.551445
# Epoch 186000: Generator Loss: 0.551445
# Epoch 188000: Generator Loss: 0.551445
# Epoch 190000: Generator Loss: 0.551445
# Epoch 192000: Generator Loss: 0.551445
# Epoch 194000: Generator Loss: 0.551445
# Epoch 196000: Generator Loss: 0.551445
# Epoch 198000: Generator Loss: 0.551445
# Epoch 200000: Generator Loss: 0.551445
# Epoch 202000: Generator Loss: 0.551445
# Epoch 204000: Generator Loss: 0.551445
# Epoch 206000: Generator Loss: 0.551445
# Epoch 208000: Generator Loss: 0.551445
# Epoch 210000: Generator Loss: 0.551445
# Epoch 212000: Generator Loss: 0.551445
# Epoch 214000: Generator Loss: 0.551445
# Epoch 216000: Generator Loss: 0.551445
# Epoch 218000: Generator Loss: 0.551445
# Epoch 220000: Generator Loss: 0.551445
# Epoch 222000: Generator Loss: 0.551445
# Epoch 224000: Generator Loss: 0.551445
# Epoch 226000: Generator Loss: 0.551445
# Epoch 228000: Generator Loss: 0.551445
# Epoch 230000: Generator Loss: 0.551445
# Epoch 232000: Generator Loss: 0.551445
# Epoch 234000: Generator Loss: 0.551445
# Epoch 236000: Generator Loss: 0.551445
# Epoch 238000: Generator Loss: 0.551445
# Epoch 240000: Generator Loss: 0.551445
# Epoch 242000: Generator Loss: 0.551445
# Epoch 244000: Generator Loss: 0.551445
# Epoch 246000: Generator Loss: 0.551445
# Epoch 248000: Generator Loss: 0.551445
# Epoch 250000: Generator Loss: 0.551445
# Epoch 252000: Generator Loss: 0.551445
# Epoch 254000: Generator Loss: 0.551445
# Epoch 256000: Generator Loss: 0.551445
# Epoch 258000: Generator Loss: 0.551445
# Epoch 260000: Generator Loss: 0.551445
# Epoch 262000: Generator Loss: 0.551445
# Epoch 264000: Generator Loss: 0.551445
# Epoch 266000: Generator Loss: 0.551445
# Epoch 268000: Generator Loss: 0.551445
# Epoch 270000: Generator Loss: 0.551445
# Epoch 272000: Generator Loss: 0.551445
# Epoch 274000: Generator Loss: 0.551445
# Epoch 276000: Generator Loss: 0.551445
# Epoch 278000: Generator Loss: 0.551445
# Epoch 280000: Generator Loss: 0.551445
# Epoch 282000: Generator Loss: 0.551445
# Epoch 284000: Generator Loss: 0.551445
# Epoch 286000: Generator Loss: 0.551445
# Epoch 288000: Generator Loss: 0.551445
# Epoch 290000: Generator Loss: 0.551445
# Epoch 292000: Generator Loss: 0.551445
# Epoch 294000: Generator Loss: 0.551445
# Epoch 296000: Generator Loss: 0.551445
# Epoch 298000: Generator Loss: 0.551445
# Epoch 300000: Generator Loss: 0.551445
# Epoch 302000: Generator Loss: 0.551445
# Epoch 304000: Generator Loss: 0.551445
# Epoch 306000: Generator Loss: 0.551445
# Epoch 308000: Generator Loss: 0.551445
# Epoch 310000: Generator Loss: 0.551445
# Epoch 312000: Generator Loss: 0.551445
# Epoch 314000: Generator Loss: 0.551445
# Epoch 316000: Generator Loss: 0.551445
# Epoch 318000: Generator Loss: 0.551445
# Epoch 320000: Generator Loss: 0.551445
# Epoch 322000: Generator Loss: 0.551445
# Epoch 324000: Generator Loss: 0.551445
# Epoch 326000: Generator Loss: 0.551445
# Epoch 328000: Generator Loss: 0.551445
# Epoch 330000: Generator Loss: 0.551445
# Epoch 332000: Generator Loss: 0.551445
# Epoch 334000: Generator Loss: 0.551445
# Epoch 336000: Generator Loss: 0.551445
# Epoch 338000: Generator Loss: 0.551445
# Epoch 340000: Generator Loss: 0.551445
# Epoch 342000: Generator Loss: 0.551445
# Epoch 344000: Generator Loss: 0.551445
# Epoch 346000: Generator Loss: 0.551445
# Epoch 348000: Generator Loss: 0.551445
# Epoch 350000: Generator Loss: 0.551445
# Epoch 352000: Generator Loss: 0.551445
# Epoch 354000: Generator Loss: 0.551445
# Epoch 356000: Generator Loss: 0.551445
# Epoch 358000: Generator Loss: 0.551445
# Epoch 360000: Generator Loss: 0.551445
# Epoch 362000: Generator Loss: 0.551445
# Epoch 364000: Generator Loss: 0.551445
# Epoch 366000: Generator Loss: 0.551445
# Epoch 368000: Generator Loss: 0.551445
# Epoch 370000: Generator Loss: 0.551445
# Epoch 372000: Generator Loss: 0.551445
# Epoch 374000: Generator Loss: 0.551445
# Epoch 376000: Generator Loss: 0.551445
# Epoch 378000: Generator Loss: 0.551445
# Epoch 380000: Generator Loss: 0.551445
# Epoch 382000: Generator Loss: 0.551445
# Epoch 384000: Generator Loss: 0.551445
# Epoch 386000: Generator Loss: 0.551445
# Epoch 388000: Generator Loss: 0.551445
# Epoch 390000: Generator Loss: 0.551445
# Epoch 392000: Generator Loss: 0.551445
# Epoch 394000: Generator Loss: 0.551445
# Epoch 396000: Generator Loss: 0.551445
# Epoch 398000: Generator Loss: 0.551445
# Epoch 400000: Generator Loss: 0.551445
# Epoch 402000: Generator Loss: 0.551445
# Epoch 404000: Generator Loss: 0.551445
# Epoch 406000: Generator Loss: 0.551445
# Epoch 408000: Generator Loss: 0.551445
# Epoch 410000: Generator Loss: 0.551445
# Epoch 412000: Generator Loss: 0.551445
# Epoch 414000: Generator Loss: 0.551445
# Epoch 416000: Generator Loss: 0.551445
# Epoch 418000: Generator Loss: 0.551445
# Epoch 420000: Generator Loss: 0.551445
# Epoch 422000: Generator Loss: 0.551445
# Epoch 424000: Generator Loss: 0.551445
# Epoch 426000: Generator Loss: 0.551445
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-d3542737d47e> in <module>()
#      67
#      68 if __name__ == '__main__':
# ---> 69   train_gan()
#
# <ipython-input-5-d3542737d47e> in train_gan()
#      58 #         train_disc.run(feed_dict={desired_label: desired,  gen_input: z})
#      59 #         if i % 5 == 0:
# ---> 60         train_gen.run(feed_dict={desired_label: desired,  gen_input: z})
#      61
#      62         if i % 2000 == 0:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in run(self, feed_dict, session)
#    2448         none, the default session will be used.
#    2449     """
# -> 2450     _run_using_default_session(self, feed_dict, self.graph, session)
#    2451
#    2452 _gradient_registry = registry.Registry("gradient")
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in _run_using_default_session(operation, feed_dict, graph, session)
#    5214                        "the operation's graph is different from the session's "
#    5215                        "graph.")
# -> 5216   session.run(operation, feed_dict)
#    5217
#    5218
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122
#    1123           if (not is_tensor_handle_feed and
# -> 1124               not subfeed_t.get_shape().is_compatible_with(np_val.shape)):
#    1125             raise ValueError('Cannot feed value of shape %r for Tensor %r, '
#    1126                              'which has shape %r' %
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/tensor_shape.py in is_compatible_with(self, other)
#    1004         return False
#    1005       for x_dim, y_dim in zip(self._dims, other.dims):
# -> 1006         if not x_dim.is_compatible_with(y_dim):
#    1007           return False
#    1008     return True
#
# KeyboardInterrupt:
