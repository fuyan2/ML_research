# %% [markdown]
# <a href="https://colab.research.google.com/github/fuyan2/ML_research/blob/master/Fred_aux3_vs_Gan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random
import math

inf = math.inf

tf.reset_default_graph()
tf.set_random_seed(1)

# Training Params
num_steps = 100000
learning_rate = 0.00002
x_dim = 2
noise_dim = 20
NUM_LABEL = 3
GAN_CLASS_COE = 10
gan_batch_size = 100*NUM_LABEL
num_data = 10000
INV_HIDDEN = 100
beta = 0.5 #1
lemda = 0.0001

#Fredrickson Params
ALPHA = 50000
BETA = 5
GAMMA = 1
LAMBDA = 0.06

# A custom initialization (see Xavier Glorot init)
def glorot_init(shape):
    return tf.random_normal(shape=shape, stddev=1. / tf.sqrt(shape[0] / 2.), dtype=tf.float32)
 
# Linear Regression 
class Generator(object):
  # G Parameters
  def __init__(self, noise_dim, NUM_LABEL, batch_size):
    self.batch_size = batch_size
    self.linear_w1 = tf.Variable(glorot_init([noise_dim+NUM_LABEL, 100]),name='glw1')
    self.linear_b1 = tf.Variable(tf.zeros([100]),name='glb1')
    self.linear_w2 = tf.Variable(glorot_init([100, 50]),name='glw2')
    self.linear_b2 = tf.Variable(tf.zeros([50]),name='glb2')
    self.linear_w3 = tf.Variable(glorot_init([50, x_dim]),name='glw3')
    self.linear_b3 = tf.Variable(tf.zeros([x_dim]),name='glb3')
    
    self.training = True

 # Build G Graph
  def __call__(self, z,y):
    z_y = tf.concat((z,y),1)
    linear_z1 = tf.nn.leaky_relu(tf.matmul(z_y,self.linear_w1) + self.linear_b1)
    linear_z2 = tf.nn.leaky_relu(tf.matmul(linear_z1,self.linear_w2) + self.linear_b2)
    out_layer = tf.matmul(linear_z2,self.linear_w3)+self.linear_b3
    return out_layer

# Logistic Regression
class Disciminator(object):
  # D Parameters
  def __init__(self):
    self.linear_w1 = tf.Variable(glorot_init([x_dim + NUM_LABEL, 100]))
    self.linear_b1 = tf.Variable(tf.zeros([100]))
    self.linear_w2 = tf.Variable(glorot_init([100, 1]))
    self.linear_b2 = tf.Variable(tf.zeros([1]))

    self.training = True

  # Build D Graph
  def __call__(self, x, y):
    x_y = tf.concat((x,y),1)
    linear1 = tf.nn.relu(tf.matmul(x_y, self.linear_w1) + self.linear_b1)
    out = tf.matmul(linear1, self.linear_w2) + self.linear_b2
    out = tf.sigmoid(out)
    return out

class Classifier(object):
  def __init__(self):
    self.linear_w1 = tf.Variable(glorot_init([x_dim, NUM_LABEL]))
    self.linear_b1 = tf.Variable(tf.zeros([NUM_LABEL]))
#     self.linear_w2 = tf.Variable(glorot_init([1, NUM_LABEL]))
#     self.linear_b2 = tf.Variable(tf.zeros([NUM_LABEL]))

    self.training = True

  # Build D Graph
  def __call__(self, x):
#     linear1 = tf.nn.relu(tf.matmul(x, self.linear_w1) + self.linear_b1)
#     out = tf.nn.softmax(tf.matmul(linear1, self.linear_w2) + self.linear_b2)
    out = tf.nn.softmax(tf.matmul(x, self.linear_w1) + self.linear_b1)
    return out
  
def lrelu(x, alpha):
  return tf.nn.relu(x) - alpha * tf.nn.relu(-x)

class Inverter_Regularizer(object):
  def __init__(self, weight_shape):
    self.w_model =  tf.Variable(glorot_init([weight_shape, INV_HIDDEN]))
    self.w_label = tf.Variable(glorot_init([NUM_LABEL, INV_HIDDEN]))
    self.w_out = tf.Variable(glorot_init([INV_HIDDEN, x_dim]))
    self.b_in = tf.Variable(tf.zeros([INV_HIDDEN]))
    self.b_out = tf.Variable(tf.zeros([x_dim]))
    
  def __call__(self, y, model_weights):
    # Input Layer
    ww = tf.matmul(model_weights, self.w_model)
    wy = tf.matmul(y, self.w_label)
    wt = tf.add(wy, ww)
    hidden_layer =  tf.add(wt, self.b_in)
    rect = lrelu(hidden_layer, 0.3)
    # Output Layer
    out_layer = tf.add(tf.matmul(rect, self.w_out), self.b_out)
    rect = lrelu(out_layer, 0.3)
    return rect
  
def plot_gan_image(name, epoch, sess):
  # Generate images from noise, using the generator network.
  fig, ax = plt.subplots()
  for i in range(NUM_LABEL):   
    # Desired label
    d_label = np.zeros([gan_batch_size, NUM_LABEL])
    d_label[:, i] = 1
    # Noise input.
    z = np.random.uniform(-1., 1., size=[gan_batch_size, noise_dim])
    g = sess.run([gen_sample], feed_dict={gen_input: z, desired_label: d_label})
    g = np.reshape(g, [gan_batch_size,2])
    if i == 0:
      ax.scatter(g[:,0], g[:,1], c='r')
    elif i == 1:
      ax.scatter(g[:,0], g[:,1], c='b')
    elif i == 2:
      ax.scatter(g[:,0], g[:,1], c='g')
      
  plt.savefig(name+epoch)

###################### Build Dataset #############################
features = tf.placeholder(tf.float32, shape=[None, x_dim])
labels = tf.placeholder(tf.float32, shape=[None, NUM_LABEL])
batch_size = tf.placeholder(tf.int64)
sample_size = tf.placeholder(tf.int64)
dataset = tf.data.Dataset.from_tensor_slices((features, labels))
dataset = dataset.shuffle(sample_size, reshuffle_each_iteration=True)
dataset = dataset.batch(batch_size, drop_remainder=True).repeat()
iterator = dataset.make_initializable_iterator()
next_batch = iterator.get_next()

mu1 = [0., 0.]
sigma1 = [[1., 0.], [0., 1.]]
mu2 = [10., 0.]
sigma2 = [[1., 0.], [0., 1.]]
mu3 = [5., 10.]
x_1 = np.random.multivariate_normal(mu1, sigma1, num_data)
x_2 = np.random.multivariate_normal(mu2, sigma1, num_data)
x_3 = np.random.multivariate_normal(mu3, sigma1, num_data)

plt.scatter(x_1[:,0], x_1[:,1], c='r')
plt.scatter(x_2[:,0], x_2[:,1], c='b')
plt.scatter(x_3[:,0], x_3[:,1], c='g')

# !label=3
x_train = np.concatenate((x_1, x_2, x_3), axis=0)
y_train = np.zeros([num_data*NUM_LABEL, NUM_LABEL])
for i in range(NUM_LABEL):
  y_train[i*num_data:(i+1)*num_data, i] = 1.
  
#aux_data is same as data1
aux_mu1 = [0., 0.]
aux_mu2 = [10., 0.]
aux_mu3 = [5., 10.]

aux_data1 = np.random.multivariate_normal(aux_mu1, sigma1, 1000)
aux_data2 = np.random.multivariate_normal(aux_mu2, sigma1, 1000)
aux_data3 = np.random.multivariate_normal(aux_mu3, sigma1, 1000)

aux_data = np.concatenate((aux_data1, aux_data2, aux_data3), axis=0)
# random.shuffle(aux_data)
plt.scatter(aux_data[:,0], aux_data[:,1], c='y')


################### Build The Classifier ####################
x = tf.placeholder(tf.float32, shape=[None, x_dim])
y = tf.placeholder(tf.float32, shape=[None, NUM_LABEL])
model = Classifier()
y_ml = model(x)
# Build Inverter Regularizer
model_weights = tf.concat([tf.reshape(model.linear_w1,[1, -1]),tf.reshape(model.linear_b1,[1, -1])] ,1) #, tf.reshape(model.linear_w2,[1, -1]), tf.reshape(model.linear_b2,[1, -1])], 1)
weight_shape = int(model_weights.shape[1])
inverter = Inverter_Regularizer(weight_shape)
inv_x = inverter(y, model_weights)

# Calculate MODEL Loss
inv_loss = tf.losses.mean_squared_error(labels=x, predictions=inv_x)
class_loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=y, logits=y_ml))
model_loss = class_loss - beta * inv_loss + lemda*tf.nn.l2_loss(model_weights)
y_pred = tf.argmax(y_ml, 1)
correct = tf.equal(tf.argmax(y_ml, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# Build Optimizer !Use model_loss
model_optimizer = tf.train.AdamOptimizer(0.001).minimize(model_loss, var_list=[model.linear_w1, model.linear_b1])#, model.linear_w2, model.linear_b2])
inverter_optimizer = tf.train.GradientDescentOptimizer(0.001).minimize(inv_loss, var_list=[inverter.w_model, inverter.w_label, inverter.w_out, inverter.b_in, inverter.b_out])
grad_model = tf.gradients(class_loss, [model.linear_w1, model.linear_b1])#, model.linear_w2, model.linear_b2])

#################### Build GAN Networks ############################
# Network Inputs
gen_input = tf.placeholder(tf.float32, shape=[None, noise_dim], name='input_noise')
aux_x = tf.placeholder(tf.float32, shape=[None, x_dim])
aux_label = model(aux_x)
desired_label = tf.one_hot(tf.argmax(aux_label, 1), NUM_LABEL) 

# Build G Network
G = Generator(noise_dim, NUM_LABEL, gan_batch_size)
gen_sample = G(gen_input,desired_label)
gen_label =  model(gen_sample)

# Build 2 D Networks (one from noise input, one from generated samples)
D = Disciminator()
disc_real = D(aux_x, desired_label)
disc_fake = D(gen_sample, desired_label)

# Build Loss
gen_weights = tf.concat([tf.reshape(G.linear_w1,[1, -1]),tf.reshape(G.linear_b1,[1, -1]), tf.reshape(G.linear_w2,[1, -1]), tf.reshape(G.linear_b2,[1, -1]), tf.reshape(G.linear_w3,[1, -1]), tf.reshape(G.linear_b3,[1, -1])], 1)
gan_class_loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=desired_label, logits=gen_label)) + 0.007 * tf.nn.l2_loss(gen_weights)
gen_loss = -tf.reduce_mean(tf.log(tf.maximum(0.00001, disc_fake))) + GAN_CLASS_COE*gan_class_loss
disc_loss = -tf.reduce_mean(tf.log(tf.maximum(0.0000001, disc_real)) + tf.log(tf.maximum(0.0000001, 1. - disc_fake)))

# G Network Variables
gen_vars = [G.linear_w1, G.linear_b1, G.linear_w2, G.linear_b2, G.linear_w3, G.linear_b3]
# D Network Variables
disc_vars = [D.linear_w1, D.linear_b1, D.linear_w2, D.linear_b2]

# Create training operations !
train_gen = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(gen_loss, var_list=gen_vars)
train_disc = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(disc_loss, var_list=disc_vars)

# Fredrickson Model Inversion Attack, Gradient Attack

def fred_mi(i, y_conv, sess, iterate, start_point):
  label_chosen = np.zeros(NUM_LABEL)
  label_chosen[i] = 1
  
  cost_x = 1 - tf.squeeze(tf.gather(y_conv, i, axis=1), 0)
  gradient_of_cost = tf.gradients(cost_x, x)
  x_inv = x - tf.scalar_mul(LAMBDA, tf.squeeze(gradient_of_cost, 0))
#   x_mi = np.zeros((1, x_dim))
  x_mi = np.reshape(start_point,[1, x_dim])
  previous_costs = [inf,inf,inf,inf,inf]

  for i in range(ALPHA):
    x_mi = sess.run(x_inv, feed_dict={x: x_mi, y: [label_chosen] })
    cost_x_mi = sess.run(cost_x, feed_dict={x: x_mi, y: [label_chosen] })
    max_cost = max(previous_costs)
    
    if(cost_x_mi > max_cost or (iterate and cost_x_mi == 0)):
      print("Early break, no ALPHA HIT")
      break;
    else:
      previous_costs.append(cost_x_mi)
      previous_costs.pop(0)

    if(i % 1000 == 0):
      print('step %d, current cost is %g' % (i, cost_x_mi))

  print('iteration hit:', i+1)
  check_pred = sess.run(correct, feed_dict={x: x_mi, y: [label_chosen] })
  print("Prediction for reconstructed image:", check_pred)
  return x_mi

# %%
def train_gan():
  # Train Classifier
  
  # Initialize the variables (i.e. assign their default value)
  init = tf.global_variables_initializer()

  # Start training
  with tf.Session() as sess:

      # Run the initializer
      sess.run(init)

      sess.run(iterator.initializer, feed_dict = {features: x_train, labels: y_train, batch_size: gan_batch_size, sample_size: 40000})

      # Train the Classifier First
      for i in range(4000):
        batch = sess.run(next_batch)
        model_optimizer.run(feed_dict={ x: batch[0], y: batch[1]})
        inverter_optimizer.run(feed_dict={ x: batch[0], y: batch[1]})
        if i % 500 == 0:
          gradients, train_accuracy = sess.run([grad_model, accuracy], feed_dict={x: batch[0], y: batch[1] })
#           print('gradients: ', gradients)
          print('Epoch %d, training accuracy %g' % (i, train_accuracy))    

      test_acc, y_prediction = sess.run([accuracy, y_pred], feed_dict={x: x_train, y: y_train})
      print("test acc:", test_acc)

      cluster1 = []
      cluster2 = []
      cluster3 = []
      for i in range(0, num_data*NUM_LABEL):
        if y_prediction[i] == 0:
          cluster1.append(x_train[i])
        elif y_prediction[i] == 1:
          cluster2.append(x_train[i])
        else:
          cluster3.append(x_train[i])

      cluster1 = np.array(cluster1)
      cluster2 = np.array(cluster2)
      cluster3 = np.array(cluster3)
      print('cluster1: ', cluster1.shape, 'cluster2: ', cluster2.shape, 'cluster3:', cluster3.shape)
      plt.scatter(cluster1[:,0], cluster1[:,1],c='r')
      plt.scatter(cluster2[:,0], cluster2[:,1],c='b')
      plt.scatter(cluster3[:,0], cluster3[:,1],c='g')
      plt.savefig('Classifier_plot')
      
      # Train Fredrickson MI
      inverted_x = np.zeros((NUM_LABEL, x_dim))
      for i in range(NUM_LABEL):
        print("i = %d" % i)
        inverted_x[i] = fred_mi(i, y_ml, sess, 1, aux_data[i*1000+500,:])[0]
#       inverted_x[0] = fred_mi(0, y_ml, sess, 1, aux_data1[5,:])[0]
#       inverted_x[1] = fred_mi(1, y_ml, sess, 1, aux_data2[5,:])[0]
#       inverted_x[2] = fred_mi(2, y_ml, sess, 1, aux_data3[5,:])[0]
  
      
      plt.scatter(inverted_x[:,0], inverted_x[:,1], marker='^', c='y')

      # Initialize Aux dataset for GAN train
      aux_label = np.zeros([1000*NUM_LABEL, NUM_LABEL])
      sess.run(iterator.initializer, feed_dict = {features: aux_data, labels: aux_label, batch_size: gan_batch_size, sample_size: 40000})
      
      #Train GAN
      for i in range(50000):      
        # Sample random noise 
        batch = sess.run(next_batch)
        z = np.random.uniform(-1., 1., size=[gan_batch_size, noise_dim])
        #! Train Discriminator
        train_disc.run(feed_dict={aux_x: batch[0],  gen_input: z})
        if i % 5 == 0:
          train_gen.run(feed_dict={aux_x: batch[0],  gen_input: z})
       
        if i % 2000 == 0:
          gl,dl,cl = sess.run([gen_loss, disc_loss, gan_class_loss], feed_dict={aux_x: batch[0],  gen_input: z})
          print('Epoch %i: Generator Loss: %f, Discriminator Loss: %f, Classification loss: %f' % (i, gl, dl, cl))
          
          plot_gan_image('gan_out',str(i), sess)
          plt.scatter(inverted_x[:,0], inverted_x[:,1], marker='^', c='y')
      

        
if __name__ == '__main__':
  train_gan()
# Out:
# Epoch 0, training accuracy 0.48
# Epoch 500, training accuracy 0.506667
# Epoch 1000, training accuracy 0.52
# Epoch 1500, training accuracy 0.563333
# Epoch 2000, training accuracy 0.616667
# Epoch 2500, training accuracy 0.633333
# Epoch 3000, training accuracy 1
# Epoch 3500, training accuracy 1
# test acc: 1.0
# cluster1:  (10000, 2) cluster2:  (10000, 2) cluster3: (10000, 2)
# i = 0
# step 0, current cost is 0.0580319
# step 1000, current cost is 0.0220726
# step 2000, current cost is 0.0134656
# step 3000, current cost is 0.00965971
# step 4000, current cost is 0.00752252
# step 5000, current cost is 0.00615609
# step 6000, current cost is 0.00520819
# step 7000, current cost is 0.00451225
# step 8000, current cost is 0.00397986
# step 9000, current cost is 0.00355953
# step 10000, current cost is 0.00321937
# step 11000, current cost is 0.00293833
# step 12000, current cost is 0.0027023
# step 13000, current cost is 0.00250119
# step 14000, current cost is 0.0023281
# step 15000, current cost is 0.00217724
# step 16000, current cost is 0.00204468
# step 17000, current cost is 0.00192738
# step 18000, current cost is 0.00182283
# step 19000, current cost is 0.00172901
# step 20000, current cost is 0.00164419
# step 21000, current cost is 0.00156742
# step 22000, current cost is 0.00149751
# step 23000, current cost is 0.00143355
# step 24000, current cost is 0.00137472
# step 25000, current cost is 0.00132078
# step 26000, current cost is 0.00127071
# step 27000, current cost is 0.00122422
# step 28000, current cost is 0.00118119
# step 29000, current cost is 0.00114095
# step 30000, current cost is 0.00110352
# step 31000, current cost is 0.00106829
# step 32000, current cost is 0.00103533
# step 33000, current cost is 0.00100428
# step 34000, current cost is 0.000975132
# step 35000, current cost is 0.000947535
# step 36000, current cost is 0.000921488
# step 37000, current cost is 0.000896811
# step 38000, current cost is 0.000873506
# step 39000, current cost is 0.000851274
# step 40000, current cost is 0.000830173
# step 41000, current cost is 0.000810087
# step 42000, current cost is 0.000791013
# step 43000, current cost is 0.000772834
# step 44000, current cost is 0.00075531
# step 45000, current cost is 0.00073868
# step 46000, current cost is 0.000722706
# step 47000, current cost is 0.000707507
# step 48000, current cost is 0.000692964
# step 49000, current cost is 0.000678778
# iteration hit: 50000
# Prediction for reconstructed image: [ True]
# i = 1
# step 0, current cost is 0.0101001
# step 1000, current cost is 0.00687581
# step 2000, current cost is 0.00520605
# step 3000, current cost is 0.00418693
# step 4000, current cost is 0.00350034
# step 5000, current cost is 0.00300682
# step 6000, current cost is 0.00263494
# step 7000, current cost is 0.00234485
# step 8000, current cost is 0.00211197
# step 9000, current cost is 0.0019213
# step 10000, current cost is 0.00176215
# step 11000, current cost is 0.00162721
# step 12000, current cost is 0.00151145
# step 13000, current cost is 0.00141114
# step 14000, current cost is 0.00132328
# step 15000, current cost is 0.00124562
# step 16000, current cost is 0.00117666
# step 17000, current cost is 0.00111479
# step 18000, current cost is 0.00105923
# step 19000, current cost is 0.00100893
# step 20000, current cost is 0.000963092
# step 21000, current cost is 0.000921369
# step 22000, current cost is 0.000883043
# step 23000, current cost is 0.000847697
# step 24000, current cost is 0.000815094
# step 25000, current cost is 0.000784993
# step 26000, current cost is 0.000756979
# step 27000, current cost is 0.000730932
# step 28000, current cost is 0.000706673
# step 29000, current cost is 0.000683784
# step 30000, current cost is 0.000662386
# step 31000, current cost is 0.000642359
# step 32000, current cost is 0.000623524
# step 33000, current cost is 0.000605822
# step 34000, current cost is 0.000588894
# step 35000, current cost is 0.00057292
# step 36000, current cost is 0.000557959
# step 37000, current cost is 0.000543654
# step 38000, current cost is 0.000530064
# step 39000, current cost is 0.00051713
# step 40000, current cost is 0.000504851
# step 41000, current cost is 0.00049305
# step 42000, current cost is 0.000481844
# step 43000, current cost is 0.000471115
# step 44000, current cost is 0.000460863
# step 45000, current cost is 0.000451267
# step 46000, current cost is 0.00044173
# step 47000, current cost is 0.00043267
# step 48000, current cost is 0.000424087
# step 49000, current cost is 0.000415742
# iteration hit: 50000
# Prediction for reconstructed image: [ True]
# i = 2
# step 0, current cost is 0.000412166
# step 1000, current cost is 0.000401199
# step 2000, current cost is 0.000390828
# step 3000, current cost is 0.000380993
# step 4000, current cost is 0.000371695
# step 5000, current cost is 0.000362754
# step 6000, current cost is 0.00035429
# step 7000, current cost is 0.000346184
# step 8000, current cost is 0.000338554
# step 9000, current cost is 0.000331163
# step 10000, current cost is 0.00032413
# step 11000, current cost is 0.000317335
# step 12000, current cost is 0.000310898
# step 13000, current cost is 0.000304699
# step 14000, current cost is 0.000298798
# step 15000, current cost is 0.000293195
# step 16000, current cost is 0.000287712
# step 17000, current cost is 0.000282347
# step 18000, current cost is 0.00027734
# step 19000, current cost is 0.000272453
# step 20000, current cost is 0.000267684
# step 21000, current cost is 0.000263155
# step 22000, current cost is 0.000258744
# step 23000, current cost is 0.000254452
# step 24000, current cost is 0.000250399
# step 25000, current cost is 0.000246465
# step 26000, current cost is 0.000242651
# step 27000, current cost is 0.000238836
# step 28000, current cost is 0.00023526
# step 29000, current cost is 0.000231802
# step 30000, current cost is 0.000228465
# step 31000, current cost is 0.000225127
# step 32000, current cost is 0.000221789
# step 33000, current cost is 0.000218689
# step 34000, current cost is 0.000215828
# step 35000, current cost is 0.000212848
# step 36000, current cost is 0.000209987
# step 37000, current cost is 0.000207245
# step 38000, current cost is 0.000204384
# step 39000, current cost is 0.000201881
# step 40000, current cost is 0.000199378
# step 41000, current cost is 0.000196874
# step 42000, current cost is 0.00019449
# step 43000, current cost is 0.000192106
# step 44000, current cost is 0.000189722
# step 45000, current cost is 0.000187457
# step 46000, current cost is 0.000185311
# step 47000, current cost is 0.000183165
# step 48000, current cost is 0.000181139
# step 49000, current cost is 0.000179112
# iteration hit: 50000
# Prediction for reconstructed image: [ True]
# Epoch 0: Generator Loss: 23.535805, Discriminator Loss: 1.162908, Classification loss: 2.301771
# Epoch 2000: Generator Loss: 22.685379, Discriminator Loss: 0.802793, Classification loss: 2.180575
# Epoch 4000: Generator Loss: 22.566912, Discriminator Loss: 0.564080, Classification loss: 2.127209
# Epoch 6000: Generator Loss: 21.684696, Discriminator Loss: 0.485657, Classification loss: 2.003917
# Epoch 8000: Generator Loss: 20.689472, Discriminator Loss: 0.423222, Classification loss: 1.875641
# Epoch 10000: Generator Loss: 20.443007, Discriminator Loss: 0.407720, Classification loss: 1.808353
# Epoch 12000: Generator Loss: 19.282099, Discriminator Loss: 0.495001, Classification loss: 1.672696
# Epoch 14000: Generator Loss: 17.786299, Discriminator Loss: 0.659950, Classification loss: 1.547197
# Epoch 16000: Generator Loss: 16.914610, Discriminator Loss: 0.667504, Classification loss: 1.482727
# Epoch 18000: Generator Loss: 15.820458, Discriminator Loss: 0.944274, Classification loss: 1.424393
# Epoch 20000: Generator Loss: 15.145563, Discriminator Loss: 1.118573, Classification loss: 1.386874
# Epoch 22000: Generator Loss: 14.551648, Discriminator Loss: 1.420290, Classification loss: 1.358461
# Epoch 24000: Generator Loss: 14.164536, Discriminator Loss: 1.548056, Classification loss: 1.336002
# Epoch 26000: Generator Loss: 13.826103, Discriminator Loss: 1.538845, Classification loss: 1.306965
# Epoch 28000: Generator Loss: 13.486712, Discriminator Loss: 1.530545, Classification loss: 1.278169
# Epoch 30000: Generator Loss: 13.167343, Discriminator Loss: 1.491474, Classification loss: 1.245577
# Epoch 32000: Generator Loss: 12.853306, Discriminator Loss: 1.467735, Classification loss: 1.213675
# Epoch 34000: Generator Loss: 12.556026, Discriminator Loss: 1.415585, Classification loss: 1.183360
# Epoch 36000: Generator Loss: 12.209822, Discriminator Loss: 1.381908, Classification loss: 1.149361
# Epoch 38000: Generator Loss: 11.920879, Discriminator Loss: 1.346960, Classification loss: 1.118760
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Epoch 40000: Generator Loss: 11.639726, Discriminator Loss: 1.381206, Classification loss: 1.092300
# Epoch 42000: Generator Loss: 11.410441, Discriminator Loss: 1.359723, Classification loss: 1.067867
# Epoch 44000: Generator Loss: 11.169601, Discriminator Loss: 1.357429, Classification loss: 1.044148
# Epoch 46000: Generator Loss: 10.913465, Discriminator Loss: 1.358198, Classification loss: 1.017733
# Epoch 48000: Generator Loss: 10.704135, Discriminator Loss: 1.359044, Classification loss: 0.997740
